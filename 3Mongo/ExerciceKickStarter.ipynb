# %% [markdown]
# #  Consignes
#
# ## Description
#
# Ouvrir le fichier ks-projects-201801.csv, il recense environ 100 000 projets KickStarter. Intégrer les données directement avec L'API Python dans une base de données Mongo.
#
# Il conviendra de bien spécifier manuellement l'ID du document. Pensez aussi à bien formatter le type des données pour profiter des méthodes implémentées par Mongo. L'ensemble de données n'est pas forcément nécessaire, c'est à vous de créer votre modèle de données.
#
# ## Questions
#
# - 1) Récupérer les 5 projets ayant reçu le plus de promesse de dons.
# - 2) Compter le nombre de projets ayant atteint leur but.
# - 3) Compter le nombre de projets pour chaque catégorie.
# - 4) Compter le nombre de projets français ayant été instanciés avant 2016.
# - 5) Récupérer les projets américains ayant demandé plus de 200 000 dollars.
# - 6) Compter le nombre de projet ayant "Sport" dans leur nom

# %%
#collection.delete_many({})

# %%
import pandas as pd
import pymongo

# %%
client = pymongo.MongoClient("mongo")
database = client['exercices']
collection = database['kickstarter']

# %%
df_ks = pd.read_csv("./data/ks-projects-201801-sample.csv")
df_ks.head()
# Out:
# /root/.local/share/virtualenvs/code-AFz48Hjb/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (6,8,10,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#            ID                                               name  \
# 0   872782264    Scott Cooper's Solo CD "A Leg Trick" (Canceled)
# 1  1326492673                                    Ohceola jewelry
# 2  1688410639  Sluff Off & Harald: Two latest EGGs are Classi...
# 3   156812982  SketchPlanner: Create and Plan- all in one bea...
# 4  1835968190    Proven sales with custom motorcycle accessories
#
#          category main_category currency    deadline   goal  \
# 0            Rock         Music      USD  2011-09-16   2000
# 1         Fashion       Fashion      USD  2012-08-22  18000
# 2  Tabletop Games         Games      USD  2016-07-19   2000
# 3       Art Books    Publishing      USD  2017-09-27  13000
# 4       Sculpture           Art      CAD  2016-02-24   5000
#
#               launched pledged       state backers country usd pledged  \
# 0  2011-08-17 06:31:31    1145    canceled      24      US        1145
# 1  2012-07-23 20:46:48    1851      failed      28      US        1851
# 2  2016-07-01 21:55:54    7534  successful     254      US        3796
# 3  2017-08-28 15:47:02   16298  successful     367      US        2670
# 4  2016-01-25 17:37:10       1      failed       1      CA    0.708148
#
#    usd_pledged_real
# 0       1145.000000
# 1       1851.000000
# 2       7534.000000
# 3      16298.000000
# 4          0.738225

# %% [markdown]
# Ce warning intervient lorsque pandas n'arrive pas à inférer le type de données. Il est sympa il précise les colones 6,8,10,12.

# %%
df_ks.columns[[6,8,10,12]]
# Out:
# Index(['goal', 'pledged', 'backers', 'usd pledged'], dtype='object')

# %% [markdown]
# ## Question 0

# %% [markdown]
# ### Nettoyer les données

# %%
df_ks.shape
# Out:
# (150000, 14)

# %%
df_ks.dtypes
# Out:
# ID                    int64
# name                 object
# category             object
# main_category        object
# currency             object
# deadline             object
# goal                 object
# launched             object
# pledged              object
# state                object
# backers              object
# country              object
# usd pledged          object
# usd_pledged_real    float64
# dtype: object

# %%
df_ks.drop(66141,0,inplace=True)

df_ks = df_ks.drop(['ID','currency','deadline','backers'], axis=1)

df_ks["launched"] = df_ks["launched"].str[:4] 

df_ks = df_ks.rename({"usd pledged":"usd_pledged"}, axis='columns')

# %%
df_ks['name'] = df_ks['name'].astype('string')
df_ks['category'] = df_ks['category'].astype('string')
df_ks['main_category'] = df_ks['main_category'].astype('string')
#df_ks['currency'] = df_ks['currency'].astype('string')
#df_ks['deadline'] = pd.to_datetime(df_ks['deadline'])
df_ks['goal'] = df_ks['goal'].astype('float64')
df_ks['launched'] = df_ks['launched'].astype('int64')
df_ks['pledged'] = df_ks['pledged'].astype('float64')
df_ks['state'] = df_ks['state'].astype('string')
#df_ks['backers'] = df_ks['backers'].astype('float64')
df_ks['country'] = df_ks['country'].astype('string')
df_ks['usd_pledged'] = df_ks['usd_pledged'].astype('float64')

df_ks.dtypes
# Out:
# name                 string
# category             string
# main_category        string
# goal                float64
# launched              int64
# pledged             float64
# state                string
# country              string
# usd_pledged         float64
# usd_pledged_real    float64
# dtype: object

# %%
df_ks = df_ks.dropna()

df_ks.head()
# Out:
#                                                 name        category  \
# 0    Scott Cooper's Solo CD "A Leg Trick" (Canceled)            Rock
# 1                                    Ohceola jewelry         Fashion
# 2  Sluff Off & Harald: Two latest EGGs are Classi...  Tabletop Games
# 3  SketchPlanner: Create and Plan- all in one bea...       Art Books
# 4    Proven sales with custom motorcycle accessories       Sculpture
#
#   main_category     goal  launched  pledged       state country  usd_pledged  \
# 0         Music   2000.0      2011   1145.0    canceled      US  1145.000000
# 1       Fashion  18000.0      2012   1851.0      failed      US  1851.000000
# 2         Games   2000.0      2016   7534.0  successful      US  3796.000000
# 3    Publishing  13000.0      2017  16298.0  successful      US  2670.000000
# 4           Art   5000.0      2016      1.0      failed      CA     0.708148
#
#    usd_pledged_real
# 0       1145.000000
# 1       1851.000000
# 2       7534.000000
# 3      16298.000000
# 4          0.738225

# %% [markdown]
# ### Importer les données

# %%
dict_df = df_ks.to_dict(orient='records')

# %%
dict_df
# Out:
# [{'name': 'Scott Cooper\'s Solo CD "A Leg Trick" (Canceled)',
#   'category': 'Rock',
#   'main_category': 'Music',
#   'goal': 2000.0,
#   'launched': 2011,
#   'pledged': 1145.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 1145.0,
#   'usd_pledged_real': 1145.0},
#  {'name': 'Ohceola jewelry',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'goal': 18000.0,
#   'launched': 2012,
#   'pledged': 1851.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 1851.0,
#   'usd_pledged_real': 1851.0},
#  {'name': 'Sluff Off & Harald: Two latest EGGs are Classics "old & new"',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'goal': 2000.0,
#   'launched': 2016,
#   'pledged': 7534.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 3796.0,
#   'usd_pledged_real': 7534.0},
#  {'name': 'SketchPlanner: Create and Plan- all in one beautiful book!',
#   'category': 'Art Books',
#   'main_category': 'Publishing',
#   'goal': 13000.0,
#   'launched': 2017,
#   'pledged': 16298.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 2670.0,
#   'usd_pledged_real': 16298.0},
#  {'name': 'Proven sales with custom motorcycle accessories',
#   'category': 'Sculpture',
#   'main_category': 'Art',
#   'goal': 5000.0,
#   'launched': 2016,
#   'pledged': 1.0,
#   'state': 'failed',
#   'country': 'CA',
#   'usd_pledged': 0.70814759,
#   'usd_pledged_real': 0.7382253063635021},
#  {'name': 'Room For Growth!',
#   'category': 'Couture',
#   'main_category': 'Fashion',
#   'goal': 2000.0,
#   'launched': 2016,
#   'pledged': 6.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 6.0,
#   'usd_pledged_real': 6.0},
#  {'name': 'Build a mini Udemy with Laravel and Vuejs',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'goal': 3000.0,
#   'launched': 2017,
#   'pledged': 155.0,
#   'state': 'live',
#   'country': 'CA',
#   'usd_pledged': 15.5639964,
#   'usd_pledged_real': 123.81180605479669},
#  {'name': 'Applitizer',
#   'category': 'Software',
#   'main_category': 'Technology',
#   'goal': 100000.0,
#   'launched': 2017,
#   'pledged': 1000.0,
#   'state': 'failed',
#   'country': 'HK',
#   'usd_pledged': 128.08538,
#   'usd_pledged_real': 127.83146699391523},
#  {'name': 'Help I Am Wolves fund their first album "ABCD" on 12" vinyl!',
#   'category': 'Music',
#   'main_category': 'Music',
#   'goal': 1000.0,
#   'launched': 2017,
#   'pledged': 1465.0,
#   'state': 'successful',
#   'country': 'BE',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 1720.2104175473205},
#  {'name': 'Eco  Bamboo Underwear funding....GOT WOOD ?',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'goal': 9500.0,
#   'launched': 2012,
#   'pledged': 1212.0,
#   'state': 'failed',
#   'country': 'GB',
#   'usd_pledged': 1928.13711852,
#   'usd_pledged_real': 1953.6728081628705},
#  {'name': 'SHAKTI: The Power of Woman',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 15000.0,
#   'launched': 2012,
#   'pledged': 18361.89,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 18361.89,
#   'usd_pledged_real': 18361.89},
#  {'name': 'Coast to Coaster',
#   'category': 'Print',
#   'main_category': 'Journalism',
#   'goal': 25000.0,
#   'launched': 2017,
#   'pledged': 1.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 1.0},
#  {'name': 'Frostbite Gaming - Minecraft HUB',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 400.0,
#   'launched': 2014,
#   'pledged': 10.0,
#   'state': 'failed',
#   'country': 'GB',
#   'usd_pledged': 15.9921958,
#   'usd_pledged_real': 15.695876693192696},
#  {'name': 'Support Ramsort album',
#   'category': 'Rock',
#   'main_category': 'Music',
#   'goal': 150000.0,
#   'launched': 2015,
#   'pledged': 10.0,
#   'state': 'failed',
#   'country': 'NO',
#   'usd_pledged': 1.2455610000000001,
#   'usd_pledged_real': 1.3387776959635849},
#  {'name': 'Red No. 95 Issue 3',
#   'category': 'Comic Books',
#   'main_category': 'Comics',
#   'goal': 800.0,
#   'launched': 2017,
#   'pledged': 955.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 35.0,
#   'usd_pledged_real': 955.0},
#  {'name': 'Alice In Wonderland!',
#   'category': 'Theater',
#   'main_category': 'Theater',
#   'goal': 220.0,
#   'launched': 2012,
#   'pledged': 320.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 320.0,
#   'usd_pledged_real': 320.0},
#  {'name': 'Un piano : 150 Pas',
#   'category': 'Performances',
#   'main_category': 'Dance',
#   'goal': 1500.0,
#   'launched': 2017,
#   'pledged': 1540.0,
#   'state': 'successful',
#   'country': 'CA',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 1274.0961363448332},
#  {'name': 'Operation Penumbra: A WWII Supernatural Adventure, Vol. 1',
#   'category': 'Comics',
#   'main_category': 'Comics',
#   'goal': 15000.0,
#   'launched': 2013,
#   'pledged': 5035.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 5035.0,
#   'usd_pledged_real': 5035.0},
#  {'name': 'Emma Rae',
#   'category': 'Drama',
#   'main_category': 'Film & Video',
#   'goal': 12000.0,
#   'launched': 2017,
#   'pledged': 13415.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 1750.0,
#   'usd_pledged_real': 13415.0},
#  {'name': 'Strange Occurrences: Performances for Non-Theater Spaces',
#   'category': 'Theater',
#   'main_category': 'Theater',
#   'goal': 3000.0,
#   'launched': 2010,
#   'pledged': 3080.98,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 3080.98,
#   'usd_pledged_real': 3080.98},
#  {'name': 'Ancient Ruins II Base Series',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'goal': 1800.0,
#   'launched': 2014,
#   'pledged': 5630.95,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 5630.95,
#   'usd_pledged_real': 5630.95},
#  {'name': 'The Craziest Thing Webseries',
#   'category': 'Webseries',
#   'main_category': 'Film & Video',
#   'goal': 30000.0,
#   'launched': 2014,
#   'pledged': 300.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 300.0,
#   'usd_pledged_real': 300.0},
#  {'name': 'Look UP! To this nice shirt!',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'goal': 3700.0,
#   'launched': 2012,
#   'pledged': 203.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 203.0,
#   'usd_pledged_real': 203.0},
#  {'name': 'Ghost Nest: Giving the Power of Design Back to the Consumer (Canceled)',
#   'category': 'Design',
#   'main_category': 'Design',
#   'goal': 18729.0,
#   'launched': 2010,
#   'pledged': 1781.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 1781.0,
#   'usd_pledged_real': 1781.0},
#  {'name': 'Elli (Canceled)',
#   'category': 'Crafts',
#   'main_category': 'Crafts',
#   'goal': 5000.0,
#   'launched': 2014,
#   'pledged': 121.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 121.0,
#   'usd_pledged_real': 121.0},
#  {'name': 'States, Firms, & Households: the search for equilibrium (2)',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 100.0,
#   'launched': 2015,
#   'pledged': 0.0,
#   'state': 'canceled',
#   'country': 'CA',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'name': "Central Florida Artisans' Guild: Community Growth",
#   'category': 'DIY',
#   'main_category': 'Crafts',
#   'goal': 2000.0,
#   'launched': 2015,
#   'pledged': 121.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 121.0,
#   'usd_pledged_real': 121.0},
#  {'name': 'Frankenstein Soft Enamel Pin',
#   'category': 'Accessories',
#   'main_category': 'Fashion',
#   'goal': 215.0,
#   'launched': 2017,
#   'pledged': 18.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 18.0},
#  {'name': 'qualMeter XT: Greater Experience on Cable/Charger Testing',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'goal': 5000.0,
#   'launched': 2017,
#   'pledged': 10655.0,
#   'state': 'successful',
#   'country': 'CA',
#   'usd_pledged': 5300.34825892,
#   'usd_pledged_real': 7887.334369679473},
#  {'name': 'Candy Coburn - "THE GOOD LIFE" New Soul Rockin\' Studio Album',
#   'category': 'Music',
#   'main_category': 'Music',
#   'goal': 15000.0,
#   'launched': 2016,
#   'pledged': 15530.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 15530.0,
#   'usd_pledged_real': 15530.0},
#  {'name': "Gentlemen's Bar",
#   'category': 'Accessories',
#   'main_category': 'Fashion',
#   'goal': 4000.0,
#   'launched': 2016,
#   'pledged': 613.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 433.0,
#   'usd_pledged_real': 613.0},
#  {'name': 'A Sickle Life',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 5000.0,
#   'launched': 2016,
#   'pledged': 60.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 60.0,
#   'usd_pledged_real': 60.0},
#  {'name': 'NYC Type',
#   'category': 'Software',
#   'main_category': 'Technology',
#   'goal': 10000.0,
#   'launched': 2012,
#   'pledged': 10106.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 10106.0,
#   'usd_pledged_real': 10106.0},
#  {'name': 'PatentSlice.com-Automated Patent Drill-Down & Analysis Tool',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'goal': 5000.0,
#   'launched': 2017,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'name': 'The Birdsongs - New CD Project',
#   'category': 'Music',
#   'main_category': 'Music',
#   'goal': 5000.0,
#   'launched': 2011,
#   'pledged': 6357.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 6357.0,
#   'usd_pledged_real': 6357.0},
#  {'name': 'Brazilian pop artist Kiko London Tour support',
#   'category': 'Music',
#   'main_category': 'Music',
#   'goal': 8000.0,
#   'launched': 2017,
#   'pledged': 1.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 1.0},
#  {'name': 'Emissary - Tabletop RPG',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'goal': 5000.0,
#   'launched': 2016,
#   'pledged': 9324.0,
#   'state': 'successful',
#   'country': 'GB',
#   'usd_pledged': 13350.07578744,
#   'usd_pledged_real': 13174.888019103872},
#  {'name': 'Desktop Museum of Card Art',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 1600.0,
#   'launched': 2014,
#   'pledged': 587.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 587.0,
#   'usd_pledged_real': 587.0},
#  {'name': 'Act for Change: Healing Minds',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 16000.0,
#   'launched': 2014,
#   'pledged': 1638.0,
#   'state': 'failed',
#   'country': 'GB',
#   'usd_pledged': 2804.4439605000002,
#   'usd_pledged_real': 2733.827358301622},
#  {'name': 'Book: Outrageously (un)loved - The fight against selfhatred',
#   'category': 'Nonfiction',
#   'main_category': 'Publishing',
#   'goal': 900.0,
#   'launched': 2015,
#   'pledged': 0.0,
#   'state': 'canceled',
#   'country': 'NL',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'name': 'Help match our 2nd NEA grant for Glory Denied',
#   'category': 'Classical Music',
#   'main_category': 'Music',
#   'goal': 2500.0,
#   'launched': 2015,
#   'pledged': 2650.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 2650.0,
#   'usd_pledged_real': 2650.0},
#  {'name': 'The Alchemy of Art Book',
#   'category': 'Mixed Media',
#   'main_category': 'Art',
#   'goal': 7770.0,
#   'launched': 2016,
#   'pledged': 25.0,
#   'state': 'canceled',
#   'country': 'CA',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 18.499334023975138},
#  {'name': 'The Om Space',
#   'category': 'Civic Design',
#   'main_category': 'Design',
#   'goal': 15000.0,
#   'launched': 2016,
#   'pledged': 1512.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 1512.0,
#   'usd_pledged_real': 1512.0},
#  {'name': 'Open Source Gemini Simulator',
#   'category': 'Gaming Hardware',
#   'main_category': 'Games',
#   'goal': 1675.0,
#   'launched': 2017,
#   'pledged': 1685.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 135.0,
#   'usd_pledged_real': 1685.0},
#  {'name': 'Tenabris Ides',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'goal': 1500.0,
#   'launched': 2015,
#   'pledged': 16.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 16.0,
#   'usd_pledged_real': 16.0},
#  {'name': 'Johnny P - Resurrected (Album)',
#   'category': 'Hip-Hop',
#   'main_category': 'Music',
#   'goal': 750.0,
#   'launched': 2013,
#   'pledged': 26.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 26.0,
#   'usd_pledged_real': 26.0},
#  {'name': 'Hope for our youth today',
#   'category': 'Illustration',
#   'main_category': 'Art',
#   'goal': 6700.0,
#   'launched': 2014,
#   'pledged': 13.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 13.0,
#   'usd_pledged_real': 13.0},
#  {'name': 'The uKeg Pressurized Growler for Fresh Beer',
#   'category': 'Drinks',
#   'main_category': 'Food',
#   'goal': 75000.0,
#   'launched': 2014,
#   'pledged': 1559525.68,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 1559525.68,
#   'usd_pledged_real': 1559525.68},
#  {'name': 'STEAM for Students',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'goal': 5000.0,
#   'launched': 2014,
#   'pledged': 25.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 25.0,
#   'usd_pledged_real': 25.0},
#  {'name': 'Cold Waters, Warm Hearts: Portraits of Women Who Fly-Fish',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 10000.0,
#   'launched': 2016,
#   'pledged': 586.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 586.0,
#   'usd_pledged_real': 586.0},
#  {'name': 'Sure Set Hook',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 15000.0,
#   'launched': 2014,
#   'pledged': 100.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 100.0,
#   'usd_pledged_real': 100.0},
#  {'name': 'Bespoke by Demian Custom Menswear',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'goal': 10000.0,
#   'launched': 2015,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'name': 'Renewable Soy + American Made Candles = LOVE',
#   'category': 'Candles',
#   'main_category': 'Crafts',
#   'goal': 1000.0,
#   'launched': 2012,
#   'pledged': 2325.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 2325.0,
#   'usd_pledged_real': 2325.0},
#  {'name': 'Spray Art on canvas series',
#   'category': 'Painting',
#   'main_category': 'Art',
#   'goal': 5000.0,
#   'launched': 2015,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'GB',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'name': "Make Rubulad's Dream Home Come True",
#   'category': 'Mixed Media',
#   'main_category': 'Art',
#   'goal': 35000.0,
#   'launched': 2011,
#   'pledged': 37248.52,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 37248.52,
#   'usd_pledged_real': 37248.52},
#  {'name': 'Bad Habit Beers',
#   'category': 'Drinks',
#   'main_category': 'Food',
#   'goal': 25000.0,
#   'launched': 2015,
#   'pledged': 7522.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 7522.0,
#   'usd_pledged_real': 7522.0},
#  {'name': 'Bring the BBBC home for Christmas (Canceled)',
#   'category': 'Music',
#   'main_category': 'Music',
#   'goal': 55000.0,
#   'launched': 2014,
#   'pledged': 1395.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 1395.0,
#   'usd_pledged_real': 1395.0},
#  {'name': 'Black Lotus Empire-issue #1',
#   'category': 'Comics',
#   'main_category': 'Comics',
#   'goal': 2500.0,
#   'launched': 2012,
#   'pledged': 3905.51,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 3905.51,
#   'usd_pledged_real': 3905.51},
#  {'name': 'Toasty the Magic Fireplace',
#   'category': "Children's Books",
#   'main_category': 'Publishing',
#   'goal': 10000.0,
#   'launched': 2017,
#   'pledged': 33.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 33.0},
#  {'name': 'Lake Forest Drone',
#   'category': 'Photography',
#   'main_category': 'Photography',
#   'goal': 875.0,
#   'launched': 2016,
#   'pledged': 103.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 103.0,
#   'usd_pledged_real': 103.0},
#  {'name': 'The Meadow Project',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 20000.0,
#   'launched': 2012,
#   'pledged': 21635.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 21635.0,
#   'usd_pledged_real': 21635.0},
#  {'name': 'Clash in the Caucuses 2016',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'goal': 17500.0,
#   'launched': 2016,
#   'pledged': 682.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 86.0,
#   'usd_pledged_real': 682.0},
#  {'name': 'Politics with Allies',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'goal': 20000.0,
#   'launched': 2017,
#   'pledged': 554.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 127.0,
#   'usd_pledged_real': 554.0},
#  {'name': 'Kawaii Heroes Soft Enamel Pins | Stickers | Commissions',
#   'category': 'Accessories',
#   'main_category': 'Fashion',
#   'goal': 800.0,
#   'launched': 2017,
#   'pledged': 23.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 23.0,
#   'usd_pledged_real': 23.0},
#  {'name': 'Martin Game Studios',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 5000.0,
#   'launched': 2014,
#   'pledged': 3.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 3.0,
#   'usd_pledged_real': 3.0},
#  {'name': 'Air Basketball',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 1500.0,
#   'launched': 2013,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'name': 'ZERUBA',
#   'category': 'Publishing',
#   'main_category': 'Publishing',
#   'goal': 1000.0,
#   'launched': 2015,
#   'pledged': 2.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 2.0,
#   'usd_pledged_real': 2.0},
#  {'name': 'Crashpads and Paddles: A Rock climbing adventure by canoe',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 1500.0,
#   'launched': 2015,
#   'pledged': 80.0,
#   'state': 'canceled',
#   'country': 'CA',
#   'usd_pledged': 65.7148416,
#   'usd_pledged_real': 65.02479070145492},
#  {'name': 'Eating Up Easter - Finishing Funds',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 30000.0,
#   'launched': 2017,
#   'pledged': 35182.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 4215.0,
#   'usd_pledged_real': 35182.0},
#  {'name': 'Clocks Cameras Computers & Murder:  What Else Can Go Wrong?',
#   'category': 'Nonfiction',
#   'main_category': 'Publishing',
#   'goal': 6000.0,
#   'launched': 2015,
#   'pledged': 900.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 900.0,
#   'usd_pledged_real': 900.0},
#  {'name': 'High Caliber Community (HC2); a place for veteran networking',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'goal': 75000.0,
#   'launched': 2017,
#   'pledged': 4196.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 1876.0,
#   'usd_pledged_real': 4196.0},
#  {'name': "Rudely Stamp'd Historical Impressions",
#   'category': 'Plays',
#   'main_category': 'Theater',
#   'goal': 6000.0,
#   'launched': 2017,
#   'pledged': 550.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 100.0,
#   'usd_pledged_real': 550.0},
#  {'name': '(Teacher) Documentary, Jack teaches Buddhist Monks English',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 2390.0,
#   'launched': 2016,
#   'pledged': 2773.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 320.0,
#   'usd_pledged_real': 2773.0},
#  {'name': 'Tarot eCards App: Tarot Reading App for mobile devices',
#   'category': 'Publishing',
#   'main_category': 'Publishing',
#   'goal': 12000.0,
#   'launched': 2013,
#   'pledged': 796.66,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 796.66,
#   'usd_pledged_real': 796.66},
#  {'name': 'Sound is Revolution',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 50000.0,
#   'launched': 2017,
#   'pledged': 11.0,
#   'state': 'failed',
#   'country': 'GB',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 14.125019261389902},
#  {'name': 'City of the Shroud',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 14000.0,
#   'launched': 2016,
#   'pledged': 16239.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 16239.0,
#   'usd_pledged_real': 16239.0},
#  {'name': "Skunk Rider's first album",
#   'category': 'Rock',
#   'main_category': 'Music',
#   'goal': 500.0,
#   'launched': 2015,
#   'pledged': 1395.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 1395.0,
#   'usd_pledged_real': 1395.0},
#  {'name': "'Jamie and Friends' - Greeting Cards",
#   'category': 'Stationery',
#   'main_category': 'Crafts',
#   'goal': 1000.0,
#   'launched': 2015,
#   'pledged': 20.0,
#   'state': 'failed',
#   'country': 'GB',
#   'usd_pledged': 31.478563800000003,
#   'usd_pledged_real': 31.15167751783433},
#  {'name': 'W.E.T West End Terminal: Outdoor Chair Show/Art Installation',
#   'category': 'Public Art',
#   'main_category': 'Art',
#   'goal': 8500.0,
#   'launched': 2011,
#   'pledged': 8644.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 8644.0,
#   'usd_pledged_real': 8644.0},
#  {'name': 'BrainScrambler',
#   'category': 'Periodicals',
#   'main_category': 'Publishing',
#   'goal': 8000.0,
#   'launched': 2012,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'name': 'Paint Ring',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'goal': 55000.0,
#   'launched': 2017,
#   'pledged': 2.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 2.0},
#  {'name': 'Just Rock Showcase and Songwriter Circle 2014 at the studio',
#   'category': 'Performance Art',
#   'main_category': 'Art',
#   'goal': 1500.0,
#   'launched': 2013,
#   'pledged': 2180.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 2180.0,
#   'usd_pledged_real': 2180.0},
#  {'name': 'BRIGADE RETURNS!',
#   'category': 'Comics',
#   'main_category': 'Comics',
#   'goal': 17500.0,
#   'launched': 2013,
#   'pledged': 35343.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 35343.0,
#   'usd_pledged_real': 35343.0},
#  {'name': 'Red Box Games Dwarves, and Goblins, and Orcs Oh MY!!',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'goal': 5000.0,
#   'launched': 2013,
#   'pledged': 39258.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 39258.0,
#   'usd_pledged_real': 39258.0},
#  {'name': 'Doodle Art to Color Returns!',
#   'category': 'Art Books',
#   'main_category': 'Publishing',
#   'goal': 25.0,
#   'launched': 2014,
#   'pledged': 25.5,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 25.5,
#   'usd_pledged_real': 25.5},
#  {'name': 'New Patent Design Pocket Sheet+',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 25000.0,
#   'launched': 2015,
#   'pledged': 190.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 190.0,
#   'usd_pledged_real': 190.0},
#  {'name': 'What I Did Today',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 5000.0,
#   'launched': 2012,
#   'pledged': 360.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 360.0,
#   'usd_pledged_real': 360.0},
#  {'name': 'The Falling Girl- Chronicles of the Closed World, Book 1',
#   'category': "Children's Books",
#   'main_category': 'Publishing',
#   'goal': 500.0,
#   'launched': 2012,
#   'pledged': 695.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 695.0,
#   'usd_pledged_real': 695.0},
#  {'name': '"Intermittent Polarity" Art book by Brent and Kayla Woodside',
#   'category': 'Illustration',
#   'main_category': 'Art',
#   'goal': 1000.0,
#   'launched': 2012,
#   'pledged': 610.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 610.0,
#   'usd_pledged_real': 610.0},
#  {'name': 'The Dark Lord and the Seamstress',
#   'category': "Children's Books",
#   'main_category': 'Publishing',
#   'goal': 5000.0,
#   'launched': 2014,
#   'pledged': 5336.0,
#   'state': 'successful',
#   'country': 'CA',
#   'usd_pledged': 4862.92048512,
#   'usd_pledged_real': 4860.630351612315},
#  {'name': "Towering Trees' First Album!",
#   'category': 'Rock',
#   'main_category': 'Music',
#   'goal': 2250.0,
#   'launched': 2013,
#   'pledged': 2267.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 2267.0,
#   'usd_pledged_real': 2267.0},
#  {'name': 'Daybook notebooks (Canceled)',
#   'category': 'Stationery',
#   'main_category': 'Crafts',
#   'goal': 1000.0,
#   'launched': 2016,
#   'pledged': 52.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 52.0,
#   'usd_pledged_real': 52.0},
#  {'name': 'Big Barbeque',
#   'category': 'Events',
#   'main_category': 'Food',
#   'goal': 20000.0,
#   'launched': 2014,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'name': 'iKlimt App: The Life & Work of Gustav Klimt',
#   'category': 'Digital Art',
#   'main_category': 'Art',
#   'goal': 5000.0,
#   'launched': 2012,
#   'pledged': 66.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 66.0,
#   'usd_pledged_real': 66.0},
#  {'name': 'Seasons in the Sanctuary',
#   'category': 'Graphic Design',
#   'main_category': 'Design',
#   'goal': 4000.0,
#   'launched': 2012,
#   'pledged': 4808.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 4808.0,
#   'usd_pledged_real': 4808.0},
#  {'name': 'Charlie Chipmink',
#   'category': "Children's Books",
#   'main_category': 'Publishing',
#   'goal': 35000.0,
#   'launched': 2017,
#   'pledged': 430.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 430.0},
#  {'name': '500 Years Later: An Oral History of Final Fantasy VII',
#   'category': 'Nonfiction',
#   'main_category': 'Publishing',
#   'goal': 38000.0,
#   'launched': 2017,
#   'pledged': 72881.0,
#   'state': 'successful',
#   'country': 'GB',
#   'usd_pledged': 52551.44488998,
#   'usd_pledged_real': 97495.75267882225},
#  {'name': 'Take every shower with Matt Gator and stop shower mat mold',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 34000.0,
#   'launched': 2017,
#   'pledged': 21.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 21.0},
#  {'name': 'The VDown Podcast Intro (Canceled)',
#   'category': 'Rock',
#   'main_category': 'Music',
#   'goal': 1100.0,
#   'launched': 2014,
#   'pledged': 0.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'name': 'XPLUS Watches: Second Release',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 10000.0,
#   'launched': 2015,
#   'pledged': 16889.0,
#   'state': 'successful',
#   'country': 'AU',
#   'usd_pledged': 11874.69592693,
#   'usd_pledged_real': 11970.37352044794},
#  {'name': 'Mathatar - An online Maths adventure game for KS2 to GCSE',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 5000.0,
#   'launched': 2016,
#   'pledged': 369.0,
#   'state': 'failed',
#   'country': 'GB',
#   'usd_pledged': 154.21025895,
#   'usd_pledged_real': 449.34242571846085},
#  {'name': 'Son of a Gun',
#   'category': 'Animation',
#   'main_category': 'Film & Video',
#   'goal': 20000.0,
#   'launched': 2011,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'name': 'Bourbon Chicken',
#   'category': 'Food',
#   'main_category': 'Food',
#   'goal': 30.0,
#   'launched': 2014,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'CA',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'name': 'T-Shirt of the Year',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'goal': 1700.0,
#   'launched': 2011,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'name': 'Nobody: A Fallout Tale',
#   'category': 'Shorts',
#   'main_category': 'Film & Video',
#   'goal': 8200.0,
#   'launched': 2015,
#   'pledged': 1229.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 1229.0,
#   'usd_pledged_real': 1229.0},
#  {'name': 'The Tower',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 50000.0,
#   'launched': 2015,
#   'pledged': 283.0,
#   'state': 'failed',
#   'country': 'GB',
#   'usd_pledged': 449.38753223,
#   'usd_pledged_real': 439.1273314092417},
#  {'name': 'AutoDock Car Organizer',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'goal': 50000.0,
#   'launched': 2017,
#   'pledged': 1775.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 1775.0},
#  {'name': 'Let Me Tell You/No Money Down David Pemberton/Sally Phillips',
#   'category': 'Nonfiction',
#   'main_category': 'Publishing',
#   'goal': 10000.0,
#   'launched': 2015,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'name': 'Kiss Kiss Missiles',
#   'category': 'Performance Art',
#   'main_category': 'Art',
#   'goal': 4000.0,
#   'launched': 2012,
#   'pledged': 4075.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 4075.0,
#   'usd_pledged_real': 4075.0},
#  {'name': 'The Fountain of Light: a luminous juggling machine',
#   'category': 'Art',
#   'main_category': 'Art',
#   'goal': 8000.0,
#   'launched': 2011,
#   'pledged': 8295.36,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 8295.36,
#   'usd_pledged_real': 8295.36},
#  {'name': 'Dead of Winter',
#   'category': 'Publishing',
#   'main_category': 'Publishing',
#   'goal': 700.0,
#   'launched': 2017,
#   'pledged': 767.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 226.0,
#   'usd_pledged_real': 767.0},
#  {'name': 'To Nowhere From Nobody: An Open Source Music Project',
#   'category': 'Pop',
#   'main_category': 'Music',
#   'goal': 2500.0,
#   'launched': 2012,
#   'pledged': 5.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 5.0,
#   'usd_pledged_real': 5.0},
#  {'name': 'Swiss Producer Battle (Canceled)',
#   'category': 'Music',
#   'main_category': 'Music',
#   'goal': 20000.0,
#   'launched': 2015,
#   'pledged': 175.0,
#   'state': 'canceled',
#   'country': 'CH',
#   'usd_pledged': 185.09312849999998,
#   'usd_pledged_real': 183.3881751304676},
#  {'name': 'Diamond by Stay high clothing',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'goal': 2000.0,
#   'launched': 2016,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'AU',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'name': 'Fruition of FORMS OF IDENTIFICATION',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'goal': 2000.0,
#   'launched': 2010,
#   'pledged': 2196.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 2196.0,
#   'usd_pledged_real': 2196.0},
#  {'name': 'CUSTOM PET PORTRAIT IN 3 STYLES ( Cat / Dog / all animals! )',
#   'category': 'Painting',
#   'main_category': 'Art',
#   'goal': 800.0,
#   'launched': 2017,
#   'pledged': 1250.0,
#   'state': 'successful',
#   'country': 'HK',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 160.74689437000075},
#  {'name': '"The \'Devil" (Canceled)',
#   'category': 'Webseries',
#   'main_category': 'Film & Video',
#   'goal': 600.0,
#   'launched': 2013,
#   'pledged': 320.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 320.0,
#   'usd_pledged_real': 320.0},
#  {'name': 'Piano Wars: Dueling Piano Competition - TV Pilot Episode',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 12500.0,
#   'launched': 2011,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'name': 'Clash Calc (Canceled)',
#   'category': 'Games',
#   'main_category': 'Games',
#   'goal': 200.0,
#   'launched': 2015,
#   'pledged': 10.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 10.0,
#   'usd_pledged_real': 10.0},
#  {'name': '"Film School Porno" My film school senior project',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 2000.0,
#   'launched': 2010,
#   'pledged': 2038.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 2038.0,
#   'usd_pledged_real': 2038.0},
#  {'name': 'Carry the Tune',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 6000.0,
#   'launched': 2014,
#   'pledged': 6756.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 6756.0,
#   'usd_pledged_real': 6756.0},
#  {'name': 'FitCraft',
#   'category': 'Games',
#   'main_category': 'Games',
#   'goal': 5000.0,
#   'launched': 2015,
#   'pledged': 1504.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 1504.0,
#   'usd_pledged_real': 1504.0},
#  {'name': 'Robert Rex Waller Jr "Fancy Free" Solo Covers LP (Pre-Order)',
#   'category': 'Country & Folk',
#   'main_category': 'Music',
#   'goal': 7000.0,
#   'launched': 2016,
#   'pledged': 9244.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 9244.0,
#   'usd_pledged_real': 9244.0},
#  {'name': 'SeaGulls',
#   'category': 'Comedy',
#   'main_category': 'Film & Video',
#   'goal': 8000.0,
#   'launched': 2015,
#   'pledged': 25.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 25.0,
#   'usd_pledged_real': 25.0},
#  {'name': 'iCROS - microscope for your smartphone, tablet or iPod touch',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 20000.0,
#   'launched': 2016,
#   'pledged': 4293.0,
#   'state': 'failed',
#   'country': 'CH',
#   'usd_pledged': 1501.75625937,
#   'usd_pledged_real': 4235.398579321231},
#  {'name': 'The Microbrew Project',
#   'category': 'Events',
#   'main_category': 'Food',
#   'goal': 15000.0,
#   'launched': 2014,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'name': 'So you want to be an entreprenuer',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'goal': 1000.0,
#   'launched': 2014,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'name': 'Zoigl Beer - The New Sheriff in Town (Canceled)',
#   'category': 'Drinks',
#   'main_category': 'Food',
#   'goal': 15000.0,
#   'launched': 2015,
#   'pledged': 3681.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 3681.0,
#   'usd_pledged_real': 3681.0},
#  {'name': 'The Eastern Addition',
#   'category': 'Food',
#   'main_category': 'Food',
#   'goal': 10000.0,
#   'launched': 2012,
#   'pledged': 11204.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 11204.0,
#   'usd_pledged_real': 11204.0},
#  {'name': 'Christian Short Video and Devotional Series',
#   'category': 'Webseries',
#   'main_category': 'Film & Video',
#   'goal': 500.0,
#   'launched': 2012,
#   'pledged': 5.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 5.0,
#   'usd_pledged_real': 5.0},
#  {'name': '"Illuminate" - Artwork Album and Film',
#   'category': 'Mixed Media',
#   'main_category': 'Art',
#   'goal': 30000.0,
#   'launched': 2015,
#   'pledged': 86.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 86.0,
#   'usd_pledged_real': 86.0},
#  {'name': 'Bonjour Felicity',
#   'category': 'Shorts',
#   'main_category': 'Film & Video',
#   'goal': 4000.0,
#   'launched': 2010,
#   'pledged': 4139.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 4139.0,
#   'usd_pledged_real': 4139.0},
#  {'name': 'Edu-tainment game Animals Flipcards',
#   'category': 'Games',
#   'main_category': 'Games',
#   'goal': 1000.0,
#   'launched': 2012,
#   'pledged': 25.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 25.0,
#   'usd_pledged_real': 25.0},
#  {'name': 'Lawsuit - the law is in your hands (Canceled)',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 40000.0,
#   'launched': 2013,
#   'pledged': 84.0,
#   'state': 'canceled',
#   'country': 'GB',
#   'usd_pledged': 130.50266796,
#   'usd_pledged_real': 134.82280431432972},
#  {'name': 'Untitled, fortyseven (47) (Canceled)',
#   'category': 'Painting',
#   'main_category': 'Art',
#   'goal': 50000.0,
#   'launched': 2016,
#   'pledged': 10701.0,
#   'state': 'canceled',
#   'country': 'AU',
#   'usd_pledged': 7625.79787779,
#   'usd_pledged_real': 8218.89400921659},
#  {'name': '"The Guided"',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 100000.0,
#   'launched': 2013,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'name': 'Custom gaming arcade cabinets',
#   'category': 'Gaming Hardware',
#   'main_category': 'Games',
#   'goal': 10000.0,
#   'launched': 2016,
#   'pledged': 4.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 4.0,
#   'usd_pledged_real': 4.0},
#  {'name': "Tumbling Bones' First Full-Length Album",
#   'category': 'Country & Folk',
#   'main_category': 'Music',
#   'goal': 5000.0,
#   'launched': 2013,
#   'pledged': 7597.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 7597.0,
#   'usd_pledged_real': 7597.0},
#  {'name': '"Epic Bill Bradley" - A Feature Length Documentary',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 22000.0,
#   'launched': 2013,
#   'pledged': 12765.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 12765.0,
#   'usd_pledged_real': 12765.0},
#  {'name': 'Two Little Boys',
#   'category': 'Shorts',
#   'main_category': 'Film & Video',
#   'goal': 25000.0,
#   'launched': 2013,
#   'pledged': 1235.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 1235.0,
#   'usd_pledged_real': 1235.0},
#  {'name': 'Janadhaar: a film by Jade Ajani and David Meek',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 2000.0,
#   'launched': 2012,
#   'pledged': 2617.26,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 2617.26,
#   'usd_pledged_real': 2617.26},
#  {'name': 'Learn Game Development by Building 100 Games.',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 750.0,
#   'launched': 2015,
#   'pledged': 46405.37,
#   'state': 'successful',
#   'country': 'CA',
#   'usd_pledged': 35257.6437041796,
#   'usd_pledged_real': 34988.5923245118},
#  {'name': 'Far from Par is a movie about a man and a talking golf ball.',
#   'category': 'Comedy',
#   'main_category': 'Film & Video',
#   'goal': 200000.0,
#   'launched': 2014,
#   'pledged': 10.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 10.0,
#   'usd_pledged_real': 10.0},
#  {'name': '626 Night Market in Southern California',
#   'category': 'Food',
#   'main_category': 'Food',
#   'goal': 9888.0,
#   'launched': 2012,
#   'pledged': 315.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 315.0,
#   'usd_pledged_real': 315.0},
#  {'name': 'The Rising: Presented by Harvest Music',
#   'category': 'Music',
#   'main_category': 'Music',
#   'goal': 50000.0,
#   'launched': 2011,
#   'pledged': 100.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 100.0,
#   'usd_pledged_real': 100.0},
#  {'name': 'Scholars',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 2000.0,
#   'launched': 2013,
#   'pledged': 2060.0,
#   'state': 'successful',
#   'country': 'GB',
#   'usd_pledged': 3354.3550414,
#   'usd_pledged_real': 3389.8862907074326},
#  {'name': 'Prehistoric Clothing & Collectibles - Dinosaur Art & More!',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'goal': 10000.0,
#   'launched': 2016,
#   'pledged': 15247.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 783.0,
#   'usd_pledged_real': 15247.0},
#  {'name': 'The Noble Tree Coffee House',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'goal': 2000.0,
#   'launched': 2017,
#   'pledged': 450.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 325.0,
#   'usd_pledged_real': 450.0},
#  {'name': 'B-U-T-T-S Limited Edition Screenprinted Shirts!',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'goal': 100.0,
#   'launched': 2016,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'name': 'Pass the Cicerone Exams with the Beer Scholar Study Guides',
#   'category': 'Nonfiction',
#   'main_category': 'Publishing',
#   'goal': 2500.0,
#   'launched': 2014,
#   'pledged': 12661.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 12661.0,
#   'usd_pledged_real': 12661.0},
#  {'name': 'Open Mic p? Baras Backe',
#   'category': 'Experimental',
#   'main_category': 'Theater',
#   'goal': 1500.0,
#   'launched': 2015,
#   'pledged': 13351.0,
#   'state': 'successful',
#   'country': 'SE',
#   'usd_pledged': 1623.12993466,
#   'usd_pledged_real': 1595.0443831164953},
#  {'name': 'Please help fund/market a Brand New Quartetto Gelato CD!',
#   'category': 'Classical Music',
#   'main_category': 'Music',
#   'goal': 10000.0,
#   'launched': 2015,
#   'pledged': 2861.0,
#   'state': 'failed',
#   'country': 'CA',
#   'usd_pledged': 2256.90007888,
#   'usd_pledged_real': 2360.755837940424},
#  {'name': 'Button-Ups 2.0 | Laces That Click',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 13000.0,
#   'launched': 2017,
#   'pledged': 32960.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 3549.0,
#   'usd_pledged_real': 32960.0},
#  {'name': 'Phaxanation & the Dust Kickers: Our Full Length Record',
#   'category': 'Music',
#   'main_category': 'Music',
#   'goal': 2000.0,
#   'launched': 2010,
#   'pledged': 78.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 78.0,
#   'usd_pledged_real': 78.0},
#  {'name': 'Daniel Boone and the Opening of the American West',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 7500.0,
#   'launched': 2014,
#   'pledged': 50.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 50.0,
#   'usd_pledged_real': 50.0},
#  {'name': 'Unexpected Visitors',
#   'category': 'Drama',
#   'main_category': 'Film & Video',
#   'goal': 1400.0,
#   'launched': 2015,
#   'pledged': 1451.0,
#   'state': 'successful',
#   'country': 'GB',
#   'usd_pledged': 2196.98025558,
#   'usd_pledged_real': 2104.57611139314},
#  {'name': 'MobilePro: a day in the life of mobile digital professionals',
#   'category': 'Webseries',
#   'main_category': 'Film & Video',
#   'goal': 4000.0,
#   'launched': 2012,
#   'pledged': 352.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 352.0,
#   'usd_pledged_real': 352.0},
#  {'name': 'The Decimo leather belt. Guarantee to last 10 years.',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 6000.0,
#   'launched': 2017,
#   'pledged': 1159.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 1159.0},
#  {'name': 'Jenns cakes startup',
#   'category': "Farmer's Markets",
#   'main_category': 'Food',
#   'goal': 500.0,
#   'launched': 2014,
#   'pledged': 26.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 26.0,
#   'usd_pledged_real': 26.0},
#  {'name': 'Ausland Jobs (Canceled)',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'goal': 15000.0,
#   'launched': 2016,
#   'pledged': 0.0,
#   'state': 'canceled',
#   'country': 'AT',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'name': 'On the roof of our house nature',
#   'category': 'Community Gardens',
#   'main_category': 'Food',
#   'goal': 18600.0,
#   'launched': 2016,
#   'pledged': 1.0,
#   'state': 'failed',
#   'country': 'CA',
#   'usd_pledged': 0.74865654,
#   'usd_pledged_real': 0.7852991989948169},
#  {'name': 'A CALL TO ADVENTURE',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 287000.0,
#   'launched': 2012,
#   'pledged': 1465.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 1465.0,
#   'usd_pledged_real': 1465.0},
#  {'name': "Dani's Delectable Mini Donuts",
#   'category': 'Food',
#   'main_category': 'Food',
#   'goal': 50000.0,
#   'launched': 2015,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'CA',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'name': 'Repossession: A Christmas Album',
#   'category': 'Metal',
#   'main_category': 'Music',
#   'goal': 1750.0,
#   'launched': 2013,
#   'pledged': 125.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 125.0,
#   'usd_pledged_real': 125.0},
#  {'name': 'Exo GP-1 GoPro Housing ï¿½ Make Your GoPro Go Further',
#   'category': 'Camera Equipment',
#   'main_category': 'Technology',
#   'goal': 60000.0,
#   'launched': 2015,
#   'pledged': 24542.0,
#   'state': 'failed',
#   'country': 'NZ',
#   'usd_pledged': 15499.5970409,
#   'usd_pledged_real': 16682.75440146829},
#  {'name': 'Emergency Cellphone & GPS Handbags by Aubry Lane',
#   'category': 'Wearables',
#   'main_category': 'Technology',
#   'goal': 10000.0,
#   'launched': 2017,
#   'pledged': 3232.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 1533.0,
#   'usd_pledged_real': 3232.0},
#  {'name': 'E-Quad. Small Electric Powered Offroad Vehicle',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 9000.0,
#   'launched': 2014,
#   'pledged': 632.0,
#   'state': 'failed',
#   'country': 'NZ',
#   'usd_pledged': 527.0914128000002,
#   'usd_pledged_real': 493.3260479275624},
#  {'name': 'Illuminate:: A Site Specific Art Installation in Detroit!!!',
#   'category': 'Public Art',
#   'main_category': 'Art',
#   'goal': 1500.0,
#   'launched': 2011,
#   'pledged': 1550.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 1550.0,
#   'usd_pledged_real': 1550.0},
#  {'name': "Point Man: the Vietnam War film Hollywood won't make!",
#   'category': 'Action',
#   'main_category': 'Film & Video',
#   'goal': 16235.0,
#   'launched': 2016,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'name': 'Googly Eyes For Rocks',
#   'category': 'Crafts',
#   'main_category': 'Crafts',
#   'goal': 20.0,
#   'launched': 2015,
#   'pledged': 57.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 57.0,
#   'usd_pledged_real': 57.0},
#  {'name': 'ELLE GREY STORIES',
#   'category': "Children's Books",
#   'main_category': 'Publishing',
#   'goal': 60000.0,
#   'launched': 2017,
#   'pledged': 1144.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 750.0,
#   'usd_pledged_real': 1144.0},
#  {'name': "Seattle's new sewing studio!",
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'goal': 3300.0,
#   'launched': 2011,
#   'pledged': 3301.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 3301.0,
#   'usd_pledged_real': 3301.0},
#  {'name': 'Clorofilia Magazine',
#   'category': 'Anthologies',
#   'main_category': 'Comics',
#   'goal': 2000.0,
#   'launched': 2014,
#   'pledged': 2537.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 2537.0,
#   'usd_pledged_real': 2537.0},
#  {'name': 'RockDudeï¿½: musical shooter game with unique soundtrack',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 5000.0,
#   'launched': 2013,
#   'pledged': 155.0,
#   'state': 'canceled',
#   'country': 'GB',
#   'usd_pledged': 230.83132115,
#   'usd_pledged_real': 240.6458624437199},
#  {'name': 'Jamestown: The First Town In America: The EP',
#   'category': 'Indie Rock',
#   'main_category': 'Music',
#   'goal': 1500.0,
#   'launched': 2012,
#   'pledged': 3128.34,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 3128.34,
#   'usd_pledged_real': 3128.34},
#  {'name': 'Beatnik Wear Spring Line Release',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'goal': 1000.0,
#   'launched': 2013,
#   'pledged': 191.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 191.0,
#   'usd_pledged_real': 191.0},
#  {'name': 'Creative Adventures',
#   'category': 'Painting',
#   'main_category': 'Art',
#   'goal': 2000.0,
#   'launched': 2012,
#   'pledged': 2281.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 2281.0,
#   'usd_pledged_real': 2281.0},
#  {'name': 'Ant Dominion',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 30000.0,
#   'launched': 2014,
#   'pledged': 5368.0,
#   'state': 'failed',
#   'country': 'CA',
#   'usd_pledged': 4941.99965336,
#   'usd_pledged_real': 4985.141158989599},
#  {'name': 'SocketCircuits -  Build electronic circuits on paper!',
#   'category': 'DIY Electronics',
#   'main_category': 'Technology',
#   'goal': 2000.0,
#   'launched': 2014,
#   'pledged': 6031.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 6031.0,
#   'usd_pledged_real': 6031.0},
#  {'name': 'Organic elephant garlic farm',
#   'category': 'Farms',
#   'main_category': 'Food',
#   'goal': 150000.0,
#   'launched': 2015,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'name': 'ChisanaRobotto Newpop Artbook with a virtual ebook version',
#   'category': 'Mixed Media',
#   'main_category': 'Art',
#   'goal': 47000.0,
#   'launched': 2014,
#   'pledged': 50.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 50.0,
#   'usd_pledged_real': 50.0},
#  {'name': 'Easy to Learn Magic Trick!',
#   'category': 'Woodworking',
#   'main_category': 'Crafts',
#   'goal': 100.0,
#   'launched': 2014,
#   'pledged': 120.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 120.0,
#   'usd_pledged_real': 120.0},
#  {'name': 'Disrupting Debt',
# ...
#   'usd_pledged': 4638.0,
#   'usd_pledged_real': 4638.0},
#  {'name': 'Breezy -- Web Series',
#   'category': 'Webseries',
#   'main_category': 'Film & Video',
#   'goal': 5000.0,
#   'launched': 2013,
#   'pledged': 5000.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 5000.0,
#   'usd_pledged_real': 5000.0},
#  {'name': 'The Keepers web series',
#   'category': 'Webseries',
#   'main_category': 'Film & Video',
#   'goal': 30000.0,
#   'launched': 2013,
#   'pledged': 16669.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 16669.0,
#   'usd_pledged_real': 16669.0},
#  {'name': 'ipad/tablet stand (Canceled)',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 65000.0,
#   'launched': 2015,
#   'pledged': 3975.0,
#   'state': 'canceled',
#   'country': 'CA',
#   'usd_pledged': 3301.832319,
#   'usd_pledged_real': 3239.3447966750873},
#  {'name': 'Deep Dive DIY',
#   'category': 'Experimental',
#   'main_category': 'Film & Video',
#   'goal': 15000.0,
#   'launched': 2015,
#   'pledged': 110.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 110.0,
#   'usd_pledged_real': 110.0},
#  {'name': 'Easy grip dip pen /Calligraphy pen /straight dip pen holder',
#   'category': 'Stationery',
#   'main_category': 'Crafts',
#   'goal': 700.0,
#   'launched': 2017,
#   'pledged': 1308.0,
#   'state': 'successful',
#   'country': 'GB',
#   'usd_pledged': 356.14763808,
#   'usd_pledged_real': 1625.0869694861346},
#  {'name': 'BandJam.it -First Video Music Social Network for New Artists',
#   'category': 'Music',
#   'main_category': 'Music',
#   'goal': 25000.0,
#   'launched': 2015,
#   'pledged': 20.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 20.0,
#   'usd_pledged_real': 20.0},
#  {'name': 'Me and the sea around the world',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 8000.0,
#   'launched': 2016,
#   'pledged': 14.0,
#   'state': 'failed',
#   'country': 'FR',
#   'usd_pledged': 15.40794738,
#   'usd_pledged_real': 15.908187034827563},
#  {'name': "Le jeu de l'amour",
#   'category': 'Playing Cards',
#   'main_category': 'Games',
#   'goal': 10000.0,
#   'launched': 2016,
#   'pledged': 1857.0,
#   'state': 'failed',
#   'country': 'FR',
#   'usd_pledged': 2011.27047927,
#   'usd_pledged_real': 2093.762684345826},
#  {'name': 'The Mighty Atom',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 10000.0,
#   'launched': 2015,
#   'pledged': 10650.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 10650.0,
#   'usd_pledged_real': 10650.0},
#  {'name': 'Kilgore Books & Comics 2017 Spring Line',
#   'category': 'Comics',
#   'main_category': 'Comics',
#   'goal': 8000.0,
#   'launched': 2017,
#   'pledged': 10169.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 2468.0,
#   'usd_pledged_real': 10169.0},
#  {'name': '"Rockin\' Everywhere"',
#   'category': 'Hip-Hop',
#   'main_category': 'Music',
#   'goal': 20000.0,
#   'launched': 2014,
#   'pledged': 15.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 15.0,
#   'usd_pledged_real': 15.0},
#  {'name': 'Andrea Beaton - With Betty and Dave',
#   'category': 'World Music',
#   'main_category': 'Music',
#   'goal': 8000.0,
#   'launched': 2016,
#   'pledged': 11845.0,
#   'state': 'successful',
#   'country': 'CA',
#   'usd_pledged': 8962.6888704,
#   'usd_pledged_real': 9057.195289799663},
#  {'name': 'Zipper',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'goal': 10000.0,
#   'launched': 2014,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'CA',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'name': "A set of 4 bumper stickers to save America's infrastructure",
#   'category': 'Design',
#   'main_category': 'Design',
#   'goal': 140.0,
#   'launched': 2016,
#   'pledged': 96.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 96.0,
#   'usd_pledged_real': 96.0},
#  {'name': 'NoHo Fringe Festival performance - #Right2Recess',
#   'category': 'Festivals',
#   'main_category': 'Theater',
#   'goal': 3000.0,
#   'launched': 2017,
#   'pledged': 540.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 540.0},
#  {'name': 'A MAN NAMED MAGICK: A Short Documentary About A Professional Magician',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 5000.0,
#   'launched': 2010,
#   'pledged': 5161.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 5161.0,
#   'usd_pledged_real': 5161.0},
#  {'name': 'PhiLOCK (Canceled)',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'goal': 100000.0,
#   'launched': 2015,
#   'pledged': 2532.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 2532.0,
#   'usd_pledged_real': 2532.0},
#  {'name': 'Cravar ï¿½ Leather Tote Bags (Canceled)',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 15000.0,
#   'launched': 2015,
#   'pledged': 6748.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 6748.0,
#   'usd_pledged_real': 6748.0},
#  {'name': 'Camper Enamel Pin',
#   'category': 'Accessories',
#   'main_category': 'Fashion',
#   'goal': 350.0,
#   'launched': 2017,
#   'pledged': 379.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 55.0,
#   'usd_pledged_real': 379.0},
#  {'name': "Plug 'N Plunge (Bathtub Overflow Pipe Plug)",
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 2500.0,
#   'launched': 2015,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'name': 'CANCELED (Canceled)',
#   'category': 'Music',
#   'main_category': 'Music',
#   'goal': 33000.0,
#   'launched': 2014,
#   'pledged': 3649.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 3649.0,
#   'usd_pledged_real': 3649.0},
#  {'name': 'Changing the Radio / Production Industry with an iOS Device',
#   'category': 'Music',
#   'main_category': 'Music',
#   'goal': 500.0,
#   'launched': 2012,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'GB',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'name': 'Better Food Control - Less Food Poisoning',
#   'category': 'Food',
#   'main_category': 'Food',
#   'goal': 200000.0,
#   'launched': 2017,
#   'pledged': 705.0,
#   'state': 'failed',
#   'country': 'NO',
#   'usd_pledged': 84.043491,
#   'usd_pledged_real': 81.55568923233541},
#  {'name': 'ROPIX JUMP ROPE SHOES',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 10000.0,
#   'launched': 2014,
#   'pledged': 10690.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 10690.0,
#   'usd_pledged_real': 10690.0},
#  {'name': 'Symphony of 1000: Be a part of it!',
#   'category': 'Classical Music',
#   'main_category': 'Music',
#   'goal': 4000.0,
#   'launched': 2013,
#   'pledged': 162.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 162.0,
#   'usd_pledged_real': 162.0},
#  {'name': 'THE POWER PRINCIPLE',
#   'category': 'Comics',
#   'main_category': 'Comics',
#   'goal': 7000.0,
#   'launched': 2012,
#   'pledged': 7263.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 7263.0,
#   'usd_pledged_real': 7263.0},
#  {'name': "'AlwaysOn' 5pee (for scale)",
#   'category': 'Fine Art',
#   'main_category': 'Photography',
#   'goal': 200.0,
#   'launched': 2014,
#   'pledged': 4.0,
#   'state': 'failed',
#   'country': 'GB',
#   'usd_pledged': 6.58338684,
#   'usd_pledged_real': 6.327812317086678},
#  {'name': 'The Prettiest Panties in the World (Canceled)',
#   'category': 'Design',
#   'main_category': 'Design',
#   'goal': 30000.0,
#   'launched': 2015,
#   'pledged': 427.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 427.0,
#   'usd_pledged_real': 427.0},
#  {'name': 'Coffee Crisis for the Sega Genesis - Metal, Aliens & Awesome',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 10000.0,
#   'launched': 2016,
#   'pledged': 15076.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 1917.0,
#   'usd_pledged_real': 15076.0},
#  {'name': 'The Black Operator',
#   'category': 'Comics',
#   'main_category': 'Comics',
#   'goal': 3300.0,
#   'launched': 2013,
#   'pledged': 1134.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 1134.0,
#   'usd_pledged_real': 1134.0},
#  {'name': 'The Athlete Spot: We Have The Ingredients For Your Success',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'goal': 50000.0,
#   'launched': 2017,
#   'pledged': 0.0,
#   'state': 'live',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'name': "Kaila Gieser's debut EP!",
#   'category': 'Music',
#   'main_category': 'Music',
#   'goal': 1500.0,
#   'launched': 2013,
#   'pledged': 25.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 25.0,
#   'usd_pledged_real': 25.0},
#  {'name': "The Revolution's Bride",
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 15000.0,
#   'launched': 2016,
#   'pledged': 10.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 10.0,
#   'usd_pledged_real': 10.0},
#  {'name': 'EZC Smartlight "The Smarter Way To Ride"',
#   'category': 'Wearables',
#   'main_category': 'Technology',
#   'goal': 400.0,
#   'launched': 2016,
#   'pledged': 1595.0,
#   'state': 'successful',
#   'country': 'CA',
#   'usd_pledged': 1195.5930195,
#   'usd_pledged_real': 1238.2578992314259},
#  {'name': 'LINJA shoes - The Finest Comfortable High Heels',
#   'category': 'Footwear',
#   'main_category': 'Fashion',
#   'goal': 25000.0,
#   'launched': 2016,
#   'pledged': 19410.0,
#   'state': 'failed',
#   'country': 'NL',
#   'usd_pledged': 4733.727817600001,
#   'usd_pledged_real': 21766.434162424022},
#  {'name': '360ï¿½ India',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 700.0,
#   'launched': 2015,
#   'pledged': 16.0,
#   'state': 'failed',
#   'country': 'GB',
#   'usd_pledged': 24.9036152,
#   'usd_pledged_real': 24.826986934798125},
#  {'name': 'The Wing Commander Orchestral Project Volume 2, Phase 1!',
#   'category': 'Jazz',
#   'main_category': 'Music',
#   'goal': 15000.0,
#   'launched': 2017,
#   'pledged': 16552.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 5130.0,
#   'usd_pledged_real': 16552.0},
#  {'name': 'My YouTube Band Project',
#   'category': 'Music',
#   'main_category': 'Music',
#   'goal': 35000.0,
#   'launched': 2012,
#   'pledged': 79937.33,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 79937.33,
#   'usd_pledged_real': 79937.33},
#  {'name': 'Help Fund a \'Miraculous\'  new Musical, "Miracolo"',
#   'category': 'Theater',
#   'main_category': 'Theater',
#   'goal': 18000.0,
#   'launched': 2013,
#   'pledged': 18000.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 18000.0,
#   'usd_pledged_real': 18000.0},
#  {'name': 'Wallets Refined & Redefined - by Obtainium',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 25000.0,
#   'launched': 2012,
#   'pledged': 88867.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 88867.0,
#   'usd_pledged_real': 88867.0},
#  {'name': 'Powermitten: EPIC performance and Album Mastering (Canceled)',
#   'category': 'Electronic Music',
#   'main_category': 'Music',
#   'goal': 1100.0,
#   'launched': 2011,
#   'pledged': 0.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'name': 'Best Man Competition Webseries',
#   'category': 'Webseries',
#   'main_category': 'Film & Video',
#   'goal': 9500.0,
#   'launched': 2013,
#   'pledged': 377.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 377.0,
#   'usd_pledged_real': 377.0},
#  {'name': 'Love Collection',
#   'category': 'Painting',
#   'main_category': 'Art',
#   'goal': 5000.0,
#   'launched': 2013,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'name': 'Pay my rent, dance a jig!',
#   'category': 'Dance',
#   'main_category': 'Dance',
#   'goal': 3000.0,
#   'launched': 2014,
#   'pledged': 1.0,
#   'state': 'failed',
#   'country': 'AU',
#   'usd_pledged': 0.93876087,
#   'usd_pledged_real': 0.9321401938851605},
#  {'name': 'The Holophonics Record a New Ska Cover Album',
#   'category': 'Rock',
#   'main_category': 'Music',
#   'goal': 2000.0,
#   'launched': 2013,
#   'pledged': 2899.5,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 2899.5,
#   'usd_pledged_real': 2899.5},
#  {'name': 'BubblePhoneCaseï¿½, Top anti-hacking phone case system.',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'goal': 10000.0,
#   'launched': 2016,
#   'pledged': 349.0,
#   'state': 'canceled',
#   'country': 'ES',
#   'usd_pledged': 383.49541128,
#   'usd_pledged_real': 368.5088589952062},
#  {'name': 'Hamtramck Labor Day Festival',
#   'category': 'Public Art',
#   'main_category': 'Art',
#   'goal': 20000.0,
#   'launched': 2012,
#   'pledged': 2366.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 2366.0,
#   'usd_pledged_real': 2366.0},
#  {'name': 'Crab Cakes',
#   'category': 'Shorts',
#   'main_category': 'Film & Video',
#   'goal': 3000.0,
#   'launched': 2012,
#   'pledged': 775.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 775.0,
#   'usd_pledged_real': 775.0},
#  {'name': 'Excellent "Made in Italy" leather shoes for man/woman',
#   'category': 'Footwear',
#   'main_category': 'Fashion',
#   'goal': 178250.0,
#   'launched': 2016,
#   'pledged': 765.0,
#   'state': 'failed',
#   'country': 'IT',
#   'usd_pledged': 344.0120416000001,
#   'usd_pledged_real': 799.1225321215919},
#  {'name': 'Twig the Fairy and the Fairly Short Fairy Tales',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 17000.0,
#   'launched': 2015,
#   'pledged': 25410.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 25410.0,
#   'usd_pledged_real': 25410.0},
#  {'name': 'Civil Architect',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 100000.0,
#   'launched': 2014,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'GB',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'name': 'GHETTO CHRONICLES The Musical Comedy Stage Play (Canceled)',
#   'category': 'Theater',
#   'main_category': 'Theater',
#   'goal': 10000.0,
#   'launched': 2011,
#   'pledged': 0.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'name': 'Flyy Magazine',
#   'category': 'Periodicals',
#   'main_category': 'Publishing',
#   'goal': 10000.0,
#   'launched': 2012,
#   'pledged': 20.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 20.0,
#   'usd_pledged_real': 20.0},
#  {'name': 'Dracucat : A vampire kitten card game',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'goal': 1900.0,
#   'launched': 2015,
#   'pledged': 2944.0,
#   'state': 'successful',
#   'country': 'FR',
#   'usd_pledged': 3295.37237632,
#   'usd_pledged_real': 3243.3980764357875},
#  {'name': "Little Baby's Ice Cream Funds for Responsible Packaging",
#   'category': 'Food',
#   'main_category': 'Food',
#   'goal': 5952.0,
#   'launched': 2012,
#   'pledged': 6314.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 6314.0,
#   'usd_pledged_real': 6314.0},
#  {'name': 'Leadseed',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'goal': 2500.0,
#   'launched': 2014,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'name': "Kid's Fruit & Veggie Garden Certificate (Canceled)",
#   'category': 'Food',
#   'main_category': 'Food',
#   'goal': 10000.0,
#   'launched': 2012,
#   'pledged': 75.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 75.0,
#   'usd_pledged_real': 75.0},
#  {'name': 'Independent Metal/Punk Band - New Recording',
#   'category': 'Metal',
#   'main_category': 'Music',
#   'goal': 800.0,
#   'launched': 2014,
#   'pledged': 960.0,
#   'state': 'successful',
#   'country': 'CA',
#   'usd_pledged': 864.5984735999997,
#   'usd_pledged_real': 871.3015066255217},
#  {'name': 'The Canada Grill Barbecue',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'goal': 25000.0,
#   'launched': 2013,
#   'pledged': 112.0,
#   'state': 'failed',
#   'country': 'CA',
#   'usd_pledged': 108.2184152,
#   'usd_pledged_real': 107.41344586170521},
#  {'name': '"Zero Day" Minimalist Survival Kit ZDSK',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 15000.0,
#   'launched': 2015,
#   'pledged': 15140.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 15140.0,
#   'usd_pledged_real': 15140.0},
#  ...]

# %%
collection.insert_many(dict_df)

# %% [markdown]
# ## Question 1

# %%
cur = collection.find().sort([("pledged",-1)]).limit(5)

list(cur)
# Out:
# [{'_id': ObjectId('5fca2048f4c9c8ca3e4ec1e8'),
#   'name': "COOLEST COOLER: 21st Century Cooler that's Actually Cooler",
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 50000.0,
#   'launched': 2014,
#   'pledged': 13285226.36,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 13285226.36,
#   'usd_pledged_real': 13285226.36},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4f1c12'),
#   'name': 'Pebble 2, Time 2 + All-New Pebble Core',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 1000000.0,
#   'launched': 2016,
#   'pledged': 12779843.49,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 12779843.49,
#   'usd_pledged_real': 12779843.49},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4ece00'),
#   'name': 'Expect the Unexpected. digiFilmï¿½ Camera by YASHICA',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 800000.0,
#   'launched': 2017,
#   'pledged': 10035296.0,
#   'state': 'successful',
#   'country': 'HK',
#   'usd_pledged': 4788.64216028,
#   'usd_pledged_real': 1285142.981546224},
#  {'_id': ObjectId('5fca2049f4c9c8ca3e4f50a9'),
#   'name': 'OUYA: A New Kind of Video Game Console',
#   'category': 'Gaming Hardware',
#   'main_category': 'Games',
#   'goal': 950000.0,
#   'launched': 2012,
#   'pledged': 8596474.58,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 8596474.58,
#   'usd_pledged_real': 8596474.58},
#  {'_id': ObjectId('5fca2049f4c9c8ca3e4fc72b'),
#   'name': 'The Everyday Backpack, Tote, and Sling',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 500000.0,
#   'launched': 2016,
#   'pledged': 6565782.5,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 1462611.0,
#   'usd_pledged_real': 6565782.5}]

# %% [markdown]
# ## Question 2

# %%
cur = collection.count_documents({"state":"successful"})
cur
# Out:
# 52998

# %% [markdown]
# ## Question 3

# %%
cur = collection.aggregate([{"$group" : {"_id" : "$category", "nombre" : {"$sum" : 1}}}])
list(cur)
# Out:
# [{'_id': 'Sound', 'nombre': 255},
#  {'_id': 'Farms', 'nombre': 482},
#  {'_id': 'Country & Folk', 'nombre': 1790},
#  {'_id': 'Science Fiction', 'nombre': 274},
#  {'_id': 'Film & Video', 'nombre': 3657},
#  {'_id': 'Drinks', 'nombre': 995},
#  {'_id': 'Painting', 'nombre': 1288},
#  {'_id': 'Nature', 'nombre': 219},
#  {'_id': 'Residencies', 'nombre': 32},
#  {'_id': 'Translations', 'nombre': 76},
#  {'_id': 'Taxidermy', 'nombre': 7},
#  {'_id': 'Playing Cards', 'nombre': 963},
#  {'_id': 'Woodworking', 'nombre': 433},
#  {'_id': 'Food', 'nombre': 4612},
#  {'_id': 'Music Videos', 'nombre': 299},
#  {'_id': 'Literary Spaces', 'nombre': 10},
#  {'_id': 'Weaving', 'nombre': 38},
#  {'_id': 'Conceptual Art', 'nombre': 393},
#  {'_id': 'Pottery', 'nombre': 40},
#  {'_id': 'Civic Design', 'nombre': 130},
#  {'_id': 'Restaurants', 'nombre': 1088},
#  {'_id': 'Graphic Novels', 'nombre': 702},
#  {'_id': 'Audio', 'nombre': 164},
#  {'_id': 'Fantasy', 'nombre': 132},
#  {'_id': 'Photography', 'nombre': 2239},
#  {'_id': 'Performances', 'nombre': 414},
#  {'_id': 'Knitting', 'nombre': 78},
#  {'_id': 'Mobile Games', 'nombre': 650},
#  {'_id': 'Flight', 'nombre': 158},
#  {'_id': 'Stationery', 'nombre': 90},
#  {'_id': 'Video Art', 'nombre': 65},
#  {'_id': "Children's Books", 'nombre': 2686},
#  {'_id': 'Chiptune', 'nombre': 10},
#  {'_id': 'Interactive Design', 'nombre': 146},
#  {'_id': 'Camera Equipment', 'nombre': 165},
#  {'_id': 'Letterpress', 'nombre': 24},
#  {'_id': 'Rock', 'nombre': 2707},
#  {'_id': 'Illustration', 'nombre': 1263},
#  {'_id': 'Action', 'nombre': 282},
#  {'_id': 'Live Games', 'nombre': 394},
#  {'_id': 'Technology', 'nombre': 2689},
#  {'_id': 'Theater', 'nombre': 2786},
#  {'_id': 'Wearables', 'nombre': 508},
#  {'_id': 'DIY', 'nombre': 480},
#  {'_id': 'Childrenswear', 'nombre': 192},
#  {'_id': 'Family', 'nombre': 130},
#  {'_id': 'Video Games', 'nombre': 4797},
#  {'_id': 'Places', 'nombre': 283},
#  {'_id': 'Typography', 'nombre': 44},
#  {'_id': 'Zines', 'nombre': 144},
#  {'_id': 'Calendars', 'nombre': 112},
#  {'_id': 'Sculpture', 'nombre': 737},
#  {'_id': 'DIY Electronics', 'nombre': 358},
#  {'_id': 'Robots', 'nombre': 237},
#  {'_id': 'Space Exploration', 'nombre': 137},
#  {'_id': 'Quilts', 'nombre': 32},
#  {'_id': 'Animation', 'nombre': 1017},
#  {'_id': 'Comic Books', 'nombre': 1032},
#  {'_id': 'Ceramics', 'nombre': 128},
#  {'_id': 'Crafts', 'nombre': 1834},
#  {'_id': 'Documentary', 'nombre': 6497},
#  {'_id': 'Fine Art', 'nombre': 290},
#  {'_id': 'Cookbooks', 'nombre': 217},
#  {'_id': 'Webseries', 'nombre': 2316},
#  {'_id': 'Metal', 'nombre': 274},
#  {'_id': 'Jazz', 'nombre': 733},
#  {'_id': 'Photo', 'nombre': 58},
#  {'_id': 'Fabrication Tools', 'nombre': 96},
#  {'_id': 'Digital Art', 'nombre': 524},
#  {'_id': 'Academic', 'nombre': 367},
#  {'_id': 'Journalism', 'nombre': 672},
#  {'_id': 'Puzzles', 'nombre': 95},
#  {'_id': 'Makerspaces', 'nombre': 91},
#  {'_id': 'Movie Theaters', 'nombre': 90},
#  {'_id': 'Publishing', 'nombre': 2147},
#  {'_id': 'Gadgets', 'nombre': 1210},
#  {'_id': 'Glass', 'nombre': 51},
#  {'_id': 'Performance Art', 'nombre': 855},
#  {'_id': 'Dance', 'nombre': 900},
#  {'_id': 'Candles', 'nombre': 168},
#  {'_id': 'Horror', 'nombre': 525},
#  {'_id': 'Comedy', 'nombre': 923},
#  {'_id': 'Narrative Film', 'nombre': 2097},
#  {'_id': 'Musical', 'nombre': 367},
#  {'_id': 'Ready-to-wear', 'nombre': 332},
#  {'_id': 'Vegan', 'nombre': 229},
#  {'_id': 'Food Trucks', 'nombre': 687},
#  {'_id': 'Installations', 'nombre': 178},
#  {'_id': 'Immersive', 'nombre': 131},
#  {'_id': 'Bacon', 'nombre': 78},
#  {'_id': 'Romance', 'nombre': 74},
#  {'_id': 'Jewelry', 'nombre': 472},
#  {'_id': 'Art Books', 'nombre': 1065},
#  {'_id': 'Hip-Hop', 'nombre': 1555},
#  {'_id': 'Nonfiction', 'nombre': 3390},
#  {'_id': 'Television', 'nombre': 401},
#  {'_id': 'Workshops', 'nombre': 59},
#  {'_id': 'Printing', 'nombre': 83},
#  {'_id': 'Games', 'nombre': 1331},
#  {'_id': 'Blues', 'nombre': 113},
#  {'_id': 'Hardware', 'nombre': 1430},
#  {'_id': 'Fashion', 'nombre': 3379},
#  {'_id': 'Apparel', 'nombre': 2827},
#  {'_id': 'People', 'nombre': 440},
#  {'_id': 'Accessories', 'nombre': 1203},
#  {'_id': 'Apps', 'nombre': 2535},
#  {'_id': 'Webcomics', 'nombre': 259},
#  {'_id': '3D Printing', 'nombre': 271},
#  {'_id': 'Music', 'nombre': 5293},
#  {'_id': 'Drama', 'nombre': 871},
#  {'_id': 'R&B', 'nombre': 172},
#  {'_id': 'Embroidery', 'nombre': 49},
#  {'_id': 'Young Adult', 'nombre': 328},
#  {'_id': 'Classical Music', 'nombre': 1064},
#  {'_id': 'Experimental', 'nombre': 357},
#  {'_id': 'Faith', 'nombre': 439},
#  {'_id': 'Art', 'nombre': 3358},
#  {'_id': 'Events', 'nombre': 321},
#  {'_id': 'Pop', 'nombre': 1302},
#  {'_id': 'Product Design', 'nombre': 8885},
#  {'_id': 'Textiles', 'nombre': 105},
#  {'_id': 'Animals', 'nombre': 97},
#  {'_id': 'Small Batch', 'nombre': 701},
#  {'_id': 'Mixed Media', 'nombre': 1118},
#  {'_id': 'Gaming Hardware', 'nombre': 178},
#  {'_id': 'Poetry', 'nombre': 532},
#  {'_id': 'Architecture', 'nombre': 300},
#  {'_id': 'Kids', 'nombre': 109},
#  {'_id': 'Tabletop Games', 'nombre': 5579},
#  {'_id': "Farmer's Markets", 'nombre': 175},
#  {'_id': 'Couture', 'nombre': 108},
#  {'_id': 'Latin', 'nombre': 63},
#  {'_id': 'Indie Rock', 'nombre': 2192},
#  {'_id': 'Footwear', 'nombre': 379},
#  {'_id': 'Video', 'nombre': 147},
#  {'_id': 'Crochet', 'nombre': 61},
#  {'_id': 'Photobooks', 'nombre': 608},
#  {'_id': 'Radio & Podcasts', 'nombre': 349},
#  {'_id': 'Literary Journals', 'nombre': 118},
#  {'_id': 'Plays', 'nombre': 539},
#  {'_id': 'Community Gardens', 'nombre': 115},
#  {'_id': 'Punk', 'nombre': 127},
#  {'_id': 'Festivals', 'nombre': 313},
#  {'_id': 'Public Art', 'nombre': 1248},
#  {'_id': 'Print', 'nombre': 287},
#  {'_id': 'Design', 'nombre': 1641},
#  {'_id': 'World Music', 'nombre': 850},
#  {'_id': 'Electronic Music', 'nombre': 858},
#  {'_id': 'Software', 'nombre': 1193},
#  {'_id': 'Graphic Design', 'nombre': 765},
#  {'_id': 'Comics', 'nombre': 1931},
#  {'_id': 'Spaces', 'nombre': 331},
#  {'_id': 'Pet Fashion', 'nombre': 51},
#  {'_id': 'Periodicals', 'nombre': 517},
#  {'_id': 'Thrillers', 'nombre': 302},
#  {'_id': 'Fiction', 'nombre': 3703},
#  {'_id': 'Web', 'nombre': 2017},
#  {'_id': 'Anthologies', 'nombre': 300},
#  {'_id': 'Shorts', 'nombre': 4857}]

# %% [markdown]
# ## Question 4

# %%
cur = collection.count_documents({"$and":[{"country":"FR"}, {"launched":{"$lt": 2016}}]})
cur
# Out:
# 330

# %% [markdown]
# ## Question 5

# %%
cur = collection.find({"$and":[{"country":"US"}, {"goal":{"$gte": 200000}}]})

cur_nb = cur.count()
print(cur_nb)

list(cur)
# Out:
# <ipython-input-19-aa6ff32004d4>:5: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   cur_nb = cur.count()
# 2170
# [{'_id': ObjectId('5fca2048f4c9c8ca3e4d9a59'),
#   'name': 'Far from Par is a movie about a man and a talking golf ball.',
#   'category': 'Comedy',
#   'main_category': 'Film & Video',
#   'goal': 200000.0,
#   'launched': 2014,
#   'pledged': 10.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 10.0,
#   'usd_pledged_real': 10.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4d9a6c'),
#   'name': 'A CALL TO ADVENTURE',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 287000.0,
#   'launched': 2012,
#   'pledged': 1465.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 1465.0,
#   'usd_pledged_real': 1465.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4d9b1e'),
#   'name': 'Storybricks, the storytelling online RPG',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 250000.0,
#   'launched': 2012,
#   'pledged': 23680.54,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 23680.54,
#   'usd_pledged_real': 23680.54},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4d9b26'),
#   'name': 'Shine On New World',
#   'category': 'Theater',
#   'main_category': 'Theater',
#   'goal': 300000.0,
#   'launched': 2013,
#   'pledged': 12314.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 12314.0,
#   'usd_pledged_real': 12314.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4d9b35'),
#   'name': 'Nightclub',
#   'category': 'Music',
#   'main_category': 'Music',
#   'goal': 3000000.0,
#   'launched': 2017,
#   'pledged': 1.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 1.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4d9cb6'),
#   'name': 'Nastaran (Wild Rose)',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 250000.0,
#   'launched': 2015,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4d9cbd'),
#   'name': 'Hubo - Extension Box for iPhone',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'goal': 250000.0,
#   'launched': 2016,
#   'pledged': 1996.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 438.0,
#   'usd_pledged_real': 1996.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4d9cdc'),
#   'name': 'Baja ATV Park (Suspended)',
#   'category': 'Live Games',
#   'main_category': 'Games',
#   'goal': 300000.0,
#   'launched': 2016,
#   'pledged': 11.0,
#   'state': 'suspended',
#   'country': 'US',
#   'usd_pledged': 11.0,
#   'usd_pledged_real': 11.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4d9cfa'),
#   'name': 'Chihuly Installation for Orlando (Pulse Nightclub)',
#   'category': 'Installations',
#   'main_category': 'Art',
#   'goal': 1000000.0,
#   'launched': 2016,
#   'pledged': 5.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 4.0,
#   'usd_pledged_real': 5.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4d9dbf'),
#   'name': 'Kurt Vonnegut: Unstuck in Time',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 250000.0,
#   'launched': 2015,
#   'pledged': 300319.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 300319.0,
#   'usd_pledged_real': 300319.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4d9e0e'),
#   'name': 'The LAKE HOPPER is a VTOL Flying Water Craft Made in America',
#   'category': 'Flight',
#   'main_category': 'Technology',
#   'goal': 3000000.0,
#   'launched': 2016,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4d9e42'),
#   'name': '"Hill" (11 For 11) (From the writer of Rudy & Hoosiers)',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 1000000.0,
#   'launched': 2012,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4d9e68'),
#   'name': 'Saints of The Classroom',
#   'category': 'Television',
#   'main_category': 'Film & Video',
#   'goal': 250000.0,
#   'launched': 2016,
#   'pledged': 3085.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 1915.0,
#   'usd_pledged_real': 3085.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4d9f00'),
#   'name': 'Hemingwrite - A Distraction Free Digital Typewriter',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 250000.0,
#   'launched': 2014,
#   'pledged': 342471.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 342471.0,
#   'usd_pledged_real': 342471.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4d9f40'),
#   'name': 'Breakfast 24/7',
#   'category': 'Food',
#   'main_category': 'Food',
#   'goal': 1000000.0,
#   'launched': 2016,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4d9f6c'),
#   'name': 'FJE REVOLT',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'goal': 500000.0,
#   'launched': 2015,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4d9f6d'),
#   'name': 'Austin City Limits 40 Year History Documentary Film',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 400000.0,
#   'launched': 2014,
#   'pledged': 9.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 9.0,
#   'usd_pledged_real': 9.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4d9fba'),
#   'name': 'Ozark Mountain Ranch',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 466000.0,
#   'launched': 2015,
#   'pledged': 1076.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 1076.0,
#   'usd_pledged_real': 1076.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4d9fc5'),
#   'name': 'STEM Lesson Plan - BotBrainï¿½ Educational Products',
#   'category': 'Software',
#   'main_category': 'Technology',
#   'goal': 279646.0,
#   'launched': 2014,
#   'pledged': 85.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 85.0,
#   'usd_pledged_real': 85.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4d9fde'),
#   'name': 'Guitar Godz VR: A 3D Rock Music Game',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 500000.0,
#   'launched': 2017,
#   'pledged': 22612.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 12311.0,
#   'usd_pledged_real': 22612.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4da023'),
#   'name': "The world's first crowd funded millionaire documentary",
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 1000000.0,
#   'launched': 2015,
#   'pledged': 171.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 171.0,
#   'usd_pledged_real': 171.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4da087'),
#   'name': 'Creating an online game, "Perdition Online".',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 350000.0,
#   'launched': 2013,
#   'pledged': 16.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 16.0,
#   'usd_pledged_real': 16.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4da0e6'),
#   'name': 'The Adventures of Billy Buskirk',
#   'category': 'Family',
#   'main_category': 'Film & Video',
#   'goal': 750000.0,
#   'launched': 2017,
#   'pledged': 1.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 1.0,
#   'usd_pledged_real': 1.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4da1c3'),
#   'name': 'MY TINSEL TOWN (Canceled)',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'goal': 577000.0,
#   'launched': 2014,
#   'pledged': 0.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4da1ce'),
#   'name': 'Moonlight 5 star (Canceled)',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'goal': 250000.0,
#   'launched': 2016,
#   'pledged': 0.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4da229'),
#   'name': 'TOMB Adventure 2',
#   'category': 'Games',
#   'main_category': 'Games',
#   'goal': 200000.0,
#   'launched': 2012,
#   'pledged': 5740.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 5740.0,
#   'usd_pledged_real': 5740.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4da25e'),
#   'name': 'The EIFLE S Smart-Mirror W/Front-Facing Camera! (Canceled)',
#   'category': 'Software',
#   'main_category': 'Technology',
#   'goal': 200000.0,
#   'launched': 2016,
#   'pledged': 4248.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 4248.0,
#   'usd_pledged_real': 4248.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4da26c'),
#   'name': 'The Brick Cafe',
#   'category': 'Food',
#   'main_category': 'Food',
#   'goal': 200000.0,
#   'launched': 2016,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4da2c4'),
#   'name': 'Dangerous Seas: A Beautiful Under Water War App (Canceled)',
#   'category': 'Mobile Games',
#   'main_category': 'Games',
#   'goal': 400000.0,
#   'launched': 2016,
#   'pledged': 146.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 146.0,
#   'usd_pledged_real': 146.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4da2ed'),
#   'name': 'ViewCoze.com | Cozy viewing from home (Canceled)',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'goal': 370000.0,
#   'launched': 2015,
#   'pledged': 80.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 80.0,
#   'usd_pledged_real': 80.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4da2f9'),
#   'name': 'Meet kubo: an electric scooter to carry all your stuff!',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'goal': 300000.0,
#   'launched': 2013,
#   'pledged': 56667.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 56667.0,
#   'usd_pledged_real': 56667.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4da320'),
#   'name': 'ONEIDNET Social Professional Commercial Corporate Platform',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'goal': 545539.0,
#   'launched': 2017,
#   'pledged': 1.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 1.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4da34e'),
#   'name': 'Civilian Cam',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'goal': 200000.0,
#   'launched': 2015,
#   'pledged': 10.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 10.0,
#   'usd_pledged_real': 10.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4da391'),
#   'name': 'The Scariest Movie Ever Created',
#   'category': 'Horror',
#   'main_category': 'Film & Video',
#   'goal': 100000000.0,
#   'launched': 2015,
#   'pledged': 1.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 1.0,
#   'usd_pledged_real': 1.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4da48a'),
#   'name': 'The SEED Project',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 250000.0,
#   'launched': 2012,
#   'pledged': 35.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 35.0,
#   'usd_pledged_real': 35.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4da4a4'),
#   'name': 'NewsRadio Season 6 (Canceled)',
#   'category': 'Television',
#   'main_category': 'Film & Video',
#   'goal': 3000000.0,
#   'launched': 2015,
#   'pledged': 101.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 101.0,
#   'usd_pledged_real': 101.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4da4ea'),
#   'name': 'Get Me Me Kids (Books, Music, Film & Games)',
#   'category': "Children's Books",
#   'main_category': 'Publishing',
#   'goal': 500000.0,
#   'launched': 2015,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4da569'),
#   'name': "Daniel's Dream",
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 2000000.0,
#   'launched': 2013,
#   'pledged': 60.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 60.0,
#   'usd_pledged_real': 60.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4da597'),
#   'name': 'iFly Hand Held Camera Crane- pan AND tilt - iPhone GoPro etc',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 444000.0,
#   'launched': 2012,
#   'pledged': 3439.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 3439.0,
#   'usd_pledged_real': 3439.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4da5d5'),
#   'name': 'GolferVox',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'goal': 1200000.0,
#   'launched': 2015,
#   'pledged': 70.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 70.0,
#   'usd_pledged_real': 70.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4da5fb'),
#   'name': 'Power Rangers | fan film reboot movie',
#   'category': 'Action',
#   'main_category': 'Film & Video',
#   'goal': 400000.0,
#   'launched': 2015,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4da6d0'),
#   'name': '"Another Network" Film Project',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'goal': 225000.0,
#   'launched': 2014,
#   'pledged': 55.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 55.0,
#   'usd_pledged_real': 55.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4da78d'),
#   'name': 'SELF-SUSTAINING ORGANIC FARM',
#   'category': 'Farms',
#   'main_category': 'Food',
#   'goal': 450000.0,
#   'launched': 2014,
#   'pledged': 11.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 11.0,
#   'usd_pledged_real': 11.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4da793'),
#   'name': 'Fuel-X-Tender',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'goal': 500000.0,
#   'launched': 2014,
#   'pledged': 272.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 272.0,
#   'usd_pledged_real': 272.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4da7a8'),
#   'name': 'Salad Barr ( the new fast food restaurant )',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'goal': 270000.0,
#   'launched': 2016,
#   'pledged': 1.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 1.0,
#   'usd_pledged_real': 1.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4da7b0'),
#   'name': 'We want your money (Suspended)',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 300000.0,
#   'launched': 2016,
#   'pledged': 123.0,
#   'state': 'suspended',
#   'country': 'US',
#   'usd_pledged': 123.0,
#   'usd_pledged_real': 123.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4da80d'),
#   'name': "Dutch's Kegs",
#   'category': 'Small Batch',
#   'main_category': 'Food',
#   'goal': 1000000.0,
#   'launched': 2015,
#   'pledged': 260.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 260.0,
#   'usd_pledged_real': 260.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4da834'),
#   'name': 'Pro Tailgater Party Plate',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'goal': 365000.0,
#   'launched': 2017,
#   'pledged': 200.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 200.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4da83e'),
#   'name': 'Gabriel Device - Free energy for everyone',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'goal': 500000.0,
#   'launched': 2017,
#   'pledged': 81.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 40.0,
#   'usd_pledged_real': 81.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4da876'),
#   'name': 'Pallet Wars, Part 1...Two More Weeks and Billions Are Ours!!',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'goal': 875000.0,
#   'launched': 2017,
#   'pledged': 5.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 5.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4da8de'),
#   'name': 'Fast Easy Lightweight Modular Cabinets PhastPhurniture',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 250000.0,
#   'launched': 2017,
#   'pledged': 710.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 200.0,
#   'usd_pledged_real': 710.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4da923'),
#   'name': 'Sonic Chao World fan game (Canceled)',
#   'category': 'Games',
#   'main_category': 'Games',
#   'goal': 1000000.0,
#   'launched': 2015,
#   'pledged': 0.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4da95e'),
#   'name': 'StreamStick: The Future of Streaming TV and Media (Canceled)',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'goal': 200000.0,
#   'launched': 2015,
#   'pledged': 4433.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 4433.0,
#   'usd_pledged_real': 4433.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4da9a1'),
#   'name': 'The Darkest Dawn',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'goal': 500000.0,
#   'launched': 2013,
#   'pledged': 5.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 5.0,
#   'usd_pledged_real': 5.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4daa46'),
#   'name': 'Adventure Combat Ops - A real life, apocalyptic video game!',
#   'category': 'Live Games',
#   'main_category': 'Games',
#   'goal': 400000.0,
#   'launched': 2014,
#   'pledged': 320.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 320.0,
#   'usd_pledged_real': 320.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4daa54'),
#   'name': 'Haboob Wind - The Movie',
#   'category': 'Drama',
#   'main_category': 'Film & Video',
#   'goal': 200000.0,
#   'launched': 2017,
#   'pledged': 125.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 100.0,
#   'usd_pledged_real': 125.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4daa84'),
#   'name': "World's First Smart Football",
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'goal': 500000.0,
#   'launched': 2015,
#   'pledged': 1.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 1.0,
#   'usd_pledged_real': 1.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4daacb'),
#   'name': 'The Maryanne Godboldo Story (Canceled)',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'goal': 250000.0,
#   'launched': 2013,
#   'pledged': 2350.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 2350.0,
#   'usd_pledged_real': 2350.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4daaf5'),
#   'name': 'M.A.C.S. (Canceled)',
#   'category': 'Space Exploration',
#   'main_category': 'Technology',
#   'goal': 400000.0,
#   'launched': 2014,
#   'pledged': 8.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 8.0,
#   'usd_pledged_real': 8.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4dab14'),
#   'name': 'Keeping my best friends dream alive after losing to cancer',
#   'category': 'DIY',
#   'main_category': 'Crafts',
#   'goal': 200000.0,
#   'launched': 2014,
#   'pledged': 5.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 5.0,
#   'usd_pledged_real': 5.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4dab47'),
#   'name': 'Planetary Annihilation - A Next Generation RTS',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 900000.0,
#   'launched': 2012,
#   'pledged': 2229344.36,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 2229344.36,
#   'usd_pledged_real': 2229344.36},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4dab49'),
#   'name': "Pontruff's Pop Shop, Pizza, and Punk Rock",
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'goal': 500000.0,
#   'launched': 2014,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4dac10'),
#   'name': 'The Good Fight of Faith',
#   'category': 'Family',
#   'main_category': 'Film & Video',
#   'goal': 1000000.0,
#   'launched': 2015,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4dac3c'),
#   'name': 'Film Adaptation of "The Traveler"',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'goal': 1000000.0,
#   'launched': 2016,
#   'pledged': 25.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 25.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4dacf3'),
#   'name': 'Boulder Creek Brewery and Cafe Rebuild (Canceled)',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'goal': 200000.0,
#   'launched': 2015,
#   'pledged': 12397.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 12397.0,
#   'usd_pledged_real': 12397.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4dad1b'),
#   'name': 'Uncommon Wealth',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'goal': 250000.0,
#   'launched': 2013,
#   'pledged': 2110.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 2110.0,
#   'usd_pledged_real': 2110.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4dad2b'),
#   'name': 'Design the Starship Enterprise Science Research Mock Up',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'goal': 313550.0,
#   'launched': 2013,
#   'pledged': 31.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 31.0,
#   'usd_pledged_real': 31.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4dad8a'),
#   'name': 'Backyard Soccer Buddy / Football Mate (Overseas)',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'goal': 2000000.0,
#   'launched': 2016,
#   'pledged': 0.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4dad90'),
#   'name': 'Frickin! Fleasï¿½ Mobile Game',
#   'category': 'Mobile Games',
#   'main_category': 'Games',
#   'goal': 200000.0,
#   'launched': 2017,
#   'pledged': 353.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 250.0,
#   'usd_pledged_real': 353.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4dadd8'),
#   'name': '"anonymous (street meat)" (Canceled)',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 1000000.0,
#   'launched': 2012,
#   'pledged': 0.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4dadf3'),
#   'name': 'Better Days',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'goal': 200000.0,
#   'launched': 2010,
#   'pledged': 50.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 50.0,
#   'usd_pledged_real': 50.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4dae1f'),
#   'name': 'Akaneiro: Demon Hunters',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 200000.0,
#   'launched': 2013,
#   'pledged': 204680.93,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 204680.93,
#   'usd_pledged_real': 204680.93},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4daed9'),
#   'name': 'Hello Space Boy!',
#   'category': 'Animation',
#   'main_category': 'Film & Video',
#   'goal': 2000000.0,
#   'launched': 2016,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4daefb'),
#   'name': 'Interactive Breastfeeding Documentary',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 210000.0,
#   'launched': 2011,
#   'pledged': 12058.3,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 12058.3,
#   'usd_pledged_real': 12058.3},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4daf07'),
#   'name': 'Aquaponics system for supplying fresh organic food.',
#   'category': 'Farms',
#   'main_category': 'Food',
#   'goal': 8000000.0,
#   'launched': 2016,
#   'pledged': 21.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 21.0,
#   'usd_pledged_real': 21.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4daf55'),
#   'name': 'After Reset RPG',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 900000.0,
#   'launched': 2013,
#   'pledged': 47939.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 47939.0,
#   'usd_pledged_real': 47939.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4daf8c'),
#   'name': 'SLAYING GIANTS #GOLIATH',
#   'category': 'Movie Theaters',
#   'main_category': 'Film & Video',
#   'goal': 350000.0,
#   'launched': 2016,
#   'pledged': 2508.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 175.0,
#   'usd_pledged_real': 2508.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4dafb5'),
#   'name': 'Fan News',
#   'category': 'Journalism',
#   'main_category': 'Journalism',
#   'goal': 275000.0,
#   'launched': 2015,
#   'pledged': 10.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 10.0,
#   'usd_pledged_real': 10.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4dafd8'),
#   'name': '*FLASHLIFE* Most Complete Emergency Survival Product Ever.',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'goal': 350000.0,
#   'launched': 2016,
#   'pledged': 1865.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 1.0,
#   'usd_pledged_real': 1865.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4db03e'),
#   'name': "Iota: Never lose sight of what's important.",
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'goal': 250000.0,
#   'launched': 2014,
#   'pledged': 282155.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 282155.0,
#   'usd_pledged_real': 282155.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4db0ad'),
#   'name': 'RHN - THE REAL HIP-HOP NETWORK TV CHANNEL  DOCUMENTARY',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 2000000.0,
#   'launched': 2014,
#   'pledged': 225.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 225.0,
#   'usd_pledged_real': 225.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4db0b6'),
#   'name': 'LAN Center',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'goal': 200000.0,
#   'launched': 2014,
#   'pledged': 2.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 2.0,
#   'usd_pledged_real': 2.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4db0b7'),
#   'name': 'jfg76tukv u',
#   'category': 'Art',
#   'main_category': 'Art',
#   'goal': 250000.0,
#   'launched': 2015,
#   'pledged': 2.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 2.0,
#   'usd_pledged_real': 2.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4db0d5'),
#   'name': 'Shaft in Asia Featured Film',
#   'category': 'Action',
#   'main_category': 'Film & Video',
#   'goal': 1000000.0,
#   'launched': 2015,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4db0fd'),
#   'name': 'P.U.R.E. Gamers',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 500000.0,
#   'launched': 2015,
#   'pledged': 25.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 25.0,
#   'usd_pledged_real': 25.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4db155'),
#   'name': 'The Hawaiian Girl Art Studio (Canceled)',
#   'category': 'Digital Art',
#   'main_category': 'Art',
#   'goal': 1100000.0,
#   'launched': 2016,
#   'pledged': 0.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4db1da'),
#   'name': 'The Rock Bar - Mobile Bar/Event Platform',
#   'category': 'Events',
#   'main_category': 'Food',
#   'goal': 200000.0,
#   'launched': 2015,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4db2e7'),
#   'name': 'The Wager',
#   'category': 'Action',
#   'main_category': 'Film & Video',
#   'goal': 200000.0,
#   'launched': 2015,
#   'pledged': 10.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 10.0,
#   'usd_pledged_real': 10.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4db327'),
#   'name': 'xFaire: A TV Device. Watch Any Content, Anytime & Anywhere',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 200000.0,
#   'launched': 2016,
#   'pledged': 3523.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 3227.0,
#   'usd_pledged_real': 3523.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4db355'),
#   'name': 'Independent Broadcasting Company',
#   'category': 'Television',
#   'main_category': 'Film & Video',
#   'goal': 700000.0,
#   'launched': 2017,
#   'pledged': 56.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 56.0,
#   'usd_pledged_real': 56.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4db3b2'),
#   'name': 'Forbidden Woods (Canceled)',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 2300000.0,
#   'launched': 2012,
#   'pledged': 0.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4db3f3'),
#   'name': "Max and Rex's Adventure",
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 200000.0,
#   'launched': 2012,
#   'pledged': 4286.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 4286.0,
#   'usd_pledged_real': 4286.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4db419'),
#   'name': 'The Guilt Free Life',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'goal': 250000.0,
#   'launched': 2014,
#   'pledged': 20.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 20.0,
#   'usd_pledged_real': 20.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4db421'),
#   'name': 'Mayacama Chocolate-Bean-to-Bar Craft Chocolate, Napa,Ca',
#   'category': 'Small Batch',
#   'main_category': 'Food',
#   'goal': 780000.0,
#   'launched': 2015,
#   'pledged': 267.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 267.0,
#   'usd_pledged_real': 267.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4db42f'),
#   'name': 'Puzzle Camp',
#   'category': 'Games',
#   'main_category': 'Games',
#   'goal': 750000.0,
#   'launched': 2014,
#   'pledged': 35.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 35.0,
#   'usd_pledged_real': 35.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4db432'),
#   'name': 'Vehroot Shelf | Use Your Phone or Tablet as Your Car Stereo',
#   'category': 'Sound',
#   'main_category': 'Technology',
#   'goal': 500000.0,
#   'launched': 2017,
#   'pledged': 5651.0,
#   'state': 'live',
#   'country': 'US',
#   'usd_pledged': 1248.0,
#   'usd_pledged_real': 5651.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4db451'),
#   'name': "THE YING YANG MURDER MYSTERY'S (Canceled)",
#   'category': 'Webseries',
#   'main_category': 'Film & Video',
#   'goal': 900000.0,
#   'launched': 2014,
#   'pledged': 0.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4db465'),
#   'name': 'Montgomery Al Concert 5FDP and VOLBEAT',
#   'category': 'Rock',
#   'main_category': 'Music',
#   'goal': 1040000.0,
#   'launched': 2014,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4db46b'),
#   'name': 'Wall Scaler',
#   'category': 'Flight',
#   'main_category': 'Technology',
#   'goal': 1000000.0,
#   'launched': 2017,
#   'pledged': 1.0,
#   'state': 'suspended',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 1.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4db49f'),
#   'name': 'Historic B&B with an in-house French Bakery in Memphis, TN',
#   'category': 'Food',
#   'main_category': 'Food',
#   'goal': 250000.0,
#   'launched': 2016,
#   'pledged': 10100.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 10100.0,
#   'usd_pledged_real': 10100.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4db4ae'),
#   'name': 'Eternal Fate',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 200000.0,
#   'launched': 2012,
#   'pledged': 12914.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 12914.0,
#   'usd_pledged_real': 12914.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4db4f7'),
#   'name': 'Angelz Landing the Movie',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 1200000.0,
#   'launched': 2014,
#   'pledged': 356.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 356.0,
#   'usd_pledged_real': 356.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4db574'),
#   'name': 'Morrison Land',
#   'category': 'Movie Theaters',
#   'main_category': 'Film & Video',
#   'goal': 250000.0,
#   'launched': 2014,
#   'pledged': 10.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 10.0,
#   'usd_pledged_real': 10.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4db58f'),
#   'name': 'Triple Espresso Goes to The Big Apple',
#   'category': 'Theater',
#   'main_category': 'Theater',
#   'goal': 300000.0,
#   'launched': 2013,
#   'pledged': 27581.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 27581.0,
#   'usd_pledged_real': 27581.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4db593'),
#   'name': 'Meetupgolf - Everything Golf, Everything Social',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'goal': 200000.0,
#   'launched': 2016,
#   'pledged': 360.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 25.0,
#   'usd_pledged_real': 360.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4db59b'),
#   'name': 'GunDetect - alerts you when it sees a gun',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'goal': 200000.0,
#   'launched': 2015,
#   'pledged': 43718.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 43718.0,
#   'usd_pledged_real': 43718.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4db657'),
#   'name': 'Take And Seek the Movie',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 250000.0,
#   'launched': 2013,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4db670'),
#   'name': 'Unsung Story: Tale of the Guardians',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 600000.0,
#   'launched': 2014,
#   'pledged': 660126.51,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 660126.51,
#   'usd_pledged_real': 660126.51},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4db71b'),
#   'name': 'Harishwar Center for Arts, Spirituality & Sustainability',
#   'category': 'Architecture',
#   'main_category': 'Design',
#   'goal': 1800000.0,
#   'launched': 2016,
#   'pledged': 614.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 614.0,
#   'usd_pledged_real': 614.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4db725'),
#   'name': "The Cancer Patient's Film Project",
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'goal': 1500000.0,
#   'launched': 2013,
#   'pledged': 275.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 275.0,
#   'usd_pledged_real': 275.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4db744'),
#   'name': "Small Change: Kids' Financial Life Skills",
#   'category': 'Software',
#   'main_category': 'Technology',
#   'goal': 250000.0,
#   'launched': 2014,
#   'pledged': 3536.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 3536.0,
#   'usd_pledged_real': 3536.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4db7b8'),
#   'name': 'Save the Williamsburg',
#   'category': 'Public Art',
#   'main_category': 'Art',
#   'goal': 40000000.0,
#   'launched': 2015,
#   'pledged': 21700.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 21700.0,
#   'usd_pledged_real': 21700.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4db7fe'),
#   'name': 'Nephilim, Nazis and the New World Order',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 500000.0,
#   'launched': 2015,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4db80e'),
#   'name': 'War At Home',
#   'category': 'Drama',
#   'main_category': 'Film & Video',
#   'goal': 340000.0,
#   'launched': 2015,
#   'pledged': 19328.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 19328.0,
#   'usd_pledged_real': 19328.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4db87b'),
#   'name': 'North East',
#   'category': 'Drama',
#   'main_category': 'Film & Video',
#   'goal': 250000.0,
#   'launched': 2017,
#   'pledged': 2.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 2.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4db89a'),
#   'name': 'The Great Pyramid, Project USA',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'goal': 300000.0,
#   'launched': 2014,
#   'pledged': 35.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 35.0,
#   'usd_pledged_real': 35.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4db8d7'),
#   'name': 'Time travel app',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'goal': 375000.0,
#   'launched': 2017,
#   'pledged': 135.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 10.0,
#   'usd_pledged_real': 135.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4db929'),
#   'name': 'Honolulu Haze (Canceled)',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'goal': 500000.0,
#   'launched': 2013,
#   'pledged': 70.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 70.0,
#   'usd_pledged_real': 70.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4db9c8'),
#   'name': 'Motor Sports Mailboxes',
#   'category': 'Crafts',
#   'main_category': 'Crafts',
#   'goal': 600000.0,
#   'launched': 2014,
#   'pledged': 200.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 200.0,
#   'usd_pledged_real': 200.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4dba58'),
#   'name': 'Patented MoveNetic Lock - New Post 9-11 Locking Method',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'goal': 350000.0,
#   'launched': 2014,
#   'pledged': 60.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 60.0,
#   'usd_pledged_real': 60.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4dbae6'),
#   'name': 'Where Is the Love? (A Dedication to Love) (Canceled)',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 200000.0,
#   'launched': 2012,
#   'pledged': 5.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 5.0,
#   'usd_pledged_real': 5.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4dbb20'),
#   'name': 'Love Over A Million Years',
#   'category': 'Movie Theaters',
#   'main_category': 'Film & Video',
#   'goal': 200000.0,
#   'launched': 2015,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4dbbaf'),
#   'name': 'Hoverboard: The Next Evolution in Personal Electric Mobility',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'goal': 500000.0,
#   'launched': 2015,
#   'pledged': 257275.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 257275.0,
#   'usd_pledged_real': 257275.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4dbbf7'),
#   'name': 'Make A South African Feature Film! (Canceled)',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'goal': 2500000.0,
#   'launched': 2011,
#   'pledged': 0.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4dbc96'),
#   'name': 'Feature-Length Movie: Secret of the Missing Grave',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 10000000.0,
#   'launched': 2013,
#   'pledged': 11975.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 11975.0,
#   'usd_pledged_real': 11975.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4dbcc4'),
#   'name': "Hey Chicago  It's all about you!",
#   'category': 'Design',
#   'main_category': 'Design',
#   'goal': 380000.0,
#   'launched': 2015,
#   'pledged': 950.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 950.0,
#   'usd_pledged_real': 950.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4dbd06'),
#   'name': 'All Points Bulletin (APB): Vendetta',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 300000.0,
#   'launched': 2013,
#   'pledged': 27614.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 27614.0,
#   'usd_pledged_real': 27614.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4dbd4e'),
#   'name': 'As Cine On TV',
#   'category': 'Translations',
#   'main_category': 'Publishing',
#   'goal': 2000000.0,
#   'launched': 2017,
#   'pledged': 192.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 50.0,
#   'usd_pledged_real': 192.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4dbd59'),
#   'name': 'The Hendrix Keg - Carbonated, Fresh, Craft Beer on Tap',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'goal': 300000.0,
#   'launched': 2017,
#   'pledged': 48307.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 9302.0,
#   'usd_pledged_real': 48307.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4dbdf3'),
#   'name': 'Supporting Disaster Relief through the Power of Music',
#   'category': 'Classical Music',
#   'main_category': 'Music',
#   'goal': 200000.0,
#   'launched': 2017,
#   'pledged': 560.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 560.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4dbe6b'),
#   'name': "#TINYHUMANSGETTIN'FRESH! Help a Veteran's Wife's Company!",
#   'category': 'Food',
#   'main_category': 'Food',
#   'goal': 200000.0,
#   'launched': 2014,
#   'pledged': 106.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 106.0,
#   'usd_pledged_real': 106.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4dbe76'),
#   'name': 'On The Wings Of A Miracle - An Animated Family Film',
#   'category': 'Animation',
#   'main_category': 'Film & Video',
#   'goal': 200000.0,
#   'launched': 2012,
#   'pledged': 4135.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 4135.0,
#   'usd_pledged_real': 4135.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4dbea6'),
#   'name': 'Love Gives Hope Art Gallery for Cultural Diversity!',
#   'category': 'Art',
#   'main_category': 'Art',
#   'goal': 300000.0,
#   'launched': 2017,
#   'pledged': 1.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 1.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4dbec5'),
#   'name': 'The "Get Home Now" Device',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'goal': 250000.0,
#   'launched': 2014,
#   'pledged': 1.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 1.0,
#   'usd_pledged_real': 1.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4dbf8f'),
#   'name': 'In Pursuit of Passion - Travel Television Series',
#   'category': 'Television',
#   'main_category': 'Film & Video',
#   'goal': 280000.0,
#   'launched': 2016,
#   'pledged': 100.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 100.0,
#   'usd_pledged_real': 100.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4dbfbc'),
#   'name': 'Welcome to the Wonderful World of AIDS',
#   'category': 'Thrillers',
#   'main_category': 'Film & Video',
#   'goal': 500000.0,
#   'launched': 2014,
#   'pledged': 2827.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 2827.0,
#   'usd_pledged_real': 2827.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4dbfd9'),
#   'name': 'The Homeless art Studio (pic from AP) FUCKING HELP OUT',
#   'category': 'Public Art',
#   'main_category': 'Art',
#   'goal': 500000.0,
#   'launched': 2016,
#   'pledged': 116.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 116.0,
#   'usd_pledged_real': 116.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4dc017'),
#   'name': 'From Dawson to Jackson Vineyards',
#   'category': 'Farms',
#   'main_category': 'Food',
#   'goal': 1000000.0,
#   'launched': 2014,
#   'pledged': 25.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 25.0,
#   'usd_pledged_real': 25.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4dc09f'),
#   'name': 'Make clear ice cubes at home.',
#   'category': 'Drinks',
#   'main_category': 'Food',
#   'goal': 200000.0,
#   'launched': 2015,
#   'pledged': 15.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 15.0,
#   'usd_pledged_real': 15.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4dc13f'),
#   'name': 'COUCH DIARIES',
#   'category': 'Publishing',
#   'main_category': 'Publishing',
#   'goal': 200000.0,
#   'launched': 2013,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4dc1b6'),
#   'name': 'Art Story',
#   'category': 'Animation',
#   'main_category': 'Film & Video',
#   'goal': 350000.0,
#   'launched': 2013,
#   'pledged': 365670.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 365670.0,
#   'usd_pledged_real': 365670.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4dc1f3'),
#   'name': 'My a MAZING Academic Profile',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'goal': 2852666.0,
#   'launched': 2014,
#   'pledged': 130.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 130.0,
#   'usd_pledged_real': 130.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4dc1f6'),
#   'name': 'Untold Universe (Canceled)',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 200000.0,
#   'launched': 2014,
#   'pledged': 5981.01,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 5981.01,
#   'usd_pledged_real': 5981.01},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4dc214'),
#   'name': 'The Hill (Canceled)',
#   'category': 'Festivals',
#   'main_category': 'Theater',
#   'goal': 1575000.0,
#   'launched': 2014,
#   'pledged': 203.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 203.0,
#   'usd_pledged_real': 203.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4dc225'),
#   'name': 'Sports Cards Unlimited (Canceled)',
#   'category': 'Playing Cards',
#   'main_category': 'Games',
#   'goal': 400000.0,
#   'launched': 2015,
#   'pledged': 0.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4dc27e'),
#   'name': 'Pushup Extreme. (Canceled)',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 215000.0,
#   'launched': 2013,
#   'pledged': 9748.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 9748.0,
#   'usd_pledged_real': 9748.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4dc328'),
#   'name': 'Everyday Dreamers Living in the Beautiful Struggle',
#   'category': 'Hip-Hop',
#   'main_category': 'Music',
#   'goal': 3500000.0,
#   'launched': 2016,
#   'pledged': 11.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 11.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4dc34f'),
#   'name': 'Top Side Dinner Show! Eat, watch, party, and always enjoy!',
#   'category': 'Movie Theaters',
#   'main_category': 'Film & Video',
#   'goal': 425000.0,
#   'launched': 2015,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4dc358'),
#   'name': 'The Real Kratos - Epic Action Film',
#   'category': 'Shorts',
#   'main_category': 'Film & Video',
#   'goal': 295000.0,
#   'launched': 2013,
#   'pledged': 251.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 251.0,
#   'usd_pledged_real': 251.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4dc35d'),
#   'name': 'My Russian Kitchen: Love Story',
#   'category': 'Food',
#   'main_category': 'Food',
#   'goal': 495000.0,
#   'launched': 2013,
#   'pledged': 150.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 150.0,
#   'usd_pledged_real': 150.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4dc37e'),
#   'name': 'The Fuffr Touch Case ï¿½ Multitouch Outside Your Smartphone',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'goal': 250000.0,
#   'launched': 2014,
#   'pledged': 11883.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 11883.0,
#   'usd_pledged_real': 11883.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4dc3d1'),
#   'name': "Joe N'Mo To Go!",
#   'category': 'Food Trucks',
#   'main_category': 'Food',
#   'goal': 400000.0,
#   'launched': 2016,
#   'pledged': 15.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 10.0,
#   'usd_pledged_real': 15.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4dc3d8'),
#   'name': "H-Hour: World's Elite",
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 200000.0,
#   'launched': 2013,
#   'pledged': 252662.28,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 252662.28,
#   'usd_pledged_real': 252662.28},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4dc3e2'),
#   'name': 'Free the sound',
#   'category': 'Music',
#   'main_category': 'Music',
#   'goal': 200000.0,
#   'launched': 2016,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4dc402'),
#   'name': 'Japanese Fighting Fish & Japanese Fighting Fish Hold Em',
#   'category': 'Playing Cards',
#   'main_category': 'Games',
#   'goal': 500000.0,
#   'launched': 2015,
#   'pledged': 10.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 10.0,
#   'usd_pledged_real': 10.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4dc4c1'),
#   'name': 'Samurai Lone Wolf',
#   'category': 'Comics',
#   'main_category': 'Comics',
# ...
#   'usd_pledged_real': 22.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4e984a'),
#   'name': 'iMSGer Inc.',
#   'category': 'Software',
#   'main_category': 'Technology',
#   'goal': 500000.0,
#   'launched': 2015,
#   'pledged': 1.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 1.0,
#   'usd_pledged_real': 1.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4e98fb'),
#   'name': 'New Palm-sized computer puts your office on beast mode!',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'goal': 500000.0,
#   'launched': 2017,
#   'pledged': 830.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 830.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4e9972'),
#   'name': "ODIN: Android 'Smart' Projector to Carry in Your Pocket",
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'goal': 250000.0,
#   'launched': 2014,
#   'pledged': 268192.0,
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged': 268192.0,
#   'usd_pledged_real': 268192.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4e9991'),
#   'name': 'Biggest Social Media Platform For Business(YouTube+Amazon+..',
#   'category': 'Design',
#   'main_category': 'Design',
#   'goal': 900000.0,
#   'launched': 2017,
#   'pledged': 30.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 30.0,
#   'usd_pledged_real': 30.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4e99e1'),
#   'name': 'BOB LAZAR:  The True Story (Canceled)',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'goal': 1100000.0,
#   'launched': 2015,
#   'pledged': 284.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 284.0,
#   'usd_pledged_real': 284.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4e9a09'),
#   'name': 'Hour of Chess: FREE Chess Sets for 12,500 schools!',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'goal': 1000000.0,
#   'launched': 2015,
#   'pledged': 432.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 432.0,
#   'usd_pledged_real': 432.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4e9a8e'),
#   'name': 'New Record Label in Dallas TX looking for investors.....',
#   'category': 'Hip-Hop',
#   'main_category': 'Music',
#   'goal': 250000.0,
#   'launched': 2016,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4e9ab1'),
#   'name': '"RICHT" Respecting Individuality Culture and Humanity Today',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'goal': 200000.0,
#   'launched': 2013,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4e9ad8'),
#   'name': 'Albert Einstein Museum',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'goal': 50000000.0,
#   'launched': 2014,
#   'pledged': 240.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 240.0,
#   'usd_pledged_real': 240.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4e9ade'),
#   'name': 'NEW MENS COLOGNE!',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'goal': 400000.0,
#   'launched': 2015,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4e9b13'),
#   'name': 'SelfiePICTEE',
#   'category': 'Wearables',
#   'main_category': 'Technology',
#   'goal': 500000.0,
#   'launched': 2015,
#   'pledged': 456.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 456.0,
#   'usd_pledged_real': 456.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4e9bbd'),
#   'name': 'China Meet World',
#   'category': 'Television',
#   'main_category': 'Film & Video',
#   'goal': 2646000.0,
#   'launched': 2014,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4e9c1d'),
#   'name': 'Forbidden Doors - The Movie',
#   'category': 'Thrillers',
#   'main_category': 'Film & Video',
#   'goal': 400000.0,
#   'launched': 2014,
#   'pledged': 10772.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 10772.0,
#   'usd_pledged_real': 10772.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4e9c5c'),
#   'name': "PrivacyAtlas - It's Your Life - Make Sure It's Protected!",
#   'category': 'Web',
#   'main_category': 'Technology',
#   'goal': 200000.0,
#   'launched': 2014,
#   'pledged': 56.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 56.0,
#   'usd_pledged_real': 56.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4e9cb3'),
#   'name': 'Thumper (Canceled)',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'goal': 500000.0,
#   'launched': 2013,
#   'pledged': 6961.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 6961.0,
#   'usd_pledged_real': 6961.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4e9cb8'),
#   'name': 'ME+ "Electricfying Our World"',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'goal': 250000.0,
#   'launched': 2014,
#   'pledged': 151.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 151.0,
#   'usd_pledged_real': 151.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4e9ce8'),
#   'name': 'www.GuysDoLunch.com',
#   'category': 'Software',
#   'main_category': 'Technology',
#   'goal': 500000.0,
#   'launched': 2015,
#   'pledged': 25.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 25.0,
#   'usd_pledged_real': 25.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4e9d8c'),
#   'name': 'PetWashSPA: The first home SPA system for your pets.',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 220000.0,
#   'launched': 2015,
#   'pledged': 1198.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 1198.0,
#   'usd_pledged_real': 1198.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4e9d8f'),
#   'name': 'imealhost.com',
#   'category': 'Food',
#   'main_category': 'Food',
#   'goal': 250000.0,
#   'launched': 2015,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4e9db1'),
#   'name': 'FOCUS ON THE OCEAN',
#   'category': 'Sculpture',
#   'main_category': 'Art',
#   'goal': 350000.0,
#   'launched': 2012,
#   'pledged': 1226.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 1226.0,
#   'usd_pledged_real': 1226.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4e9e30'),
#   'name': 'Ground Branch',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 425000.0,
#   'launched': 2012,
#   'pledged': 111111.54,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 111111.54,
#   'usd_pledged_real': 111111.54},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4e9f69'),
#   'name': 'Leviathans Online: Monsters In The Sky (Canceled)',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 300000.0,
#   'launched': 2012,
#   'pledged': 10556.03,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 10556.03,
#   'usd_pledged_real': 10556.03},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4e9f84'),
#   'name': "William Malone's THALLIUM'S BOX",
#   'category': 'Horror',
#   'main_category': 'Film & Video',
#   'goal': 350000.0,
#   'launched': 2015,
#   'pledged': 19410.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 19410.0,
#   'usd_pledged_real': 19410.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4e9fd8'),
#   'name': '"PG" Reanimated Cartoons Tha Movie',
#   'category': 'Animation',
#   'main_category': 'Film & Video',
#   'goal': 100000000.0,
#   'launched': 2015,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4e9fee'),
#   'name': 'SportsBucketList.net',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'goal': 250000.0,
#   'launched': 2015,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4ea000'),
#   'name': 'Bridging the Minooka area to "Back in the Day"',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'goal': 200000.0,
#   'launched': 2014,
#   'pledged': 1.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 1.0,
#   'usd_pledged_real': 1.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4ea008'),
#   'name': 'DMG Recording Studio',
#   'category': 'Music',
#   'main_category': 'Music',
#   'goal': 250000.0,
#   'launched': 2015,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4ea01c'),
#   'name': 'ProTap: Draft Beer, Wine, and Cold Beverage Dispenser',
#   'category': 'Drinks',
#   'main_category': 'Food',
#   'goal': 350000.0,
#   'launched': 2017,
#   'pledged': 7188.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 3565.0,
#   'usd_pledged_real': 7188.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4ea03c'),
#   'name': 'The Bobcat Exterior Rodent Bait Station',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'goal': 225000.0,
#   'launched': 2015,
#   'pledged': 179.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 179.0,
#   'usd_pledged_real': 179.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4ea048'),
#   'name': 'Edesia: Fresh, homemade and delicious Italian food!',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'goal': 500000.0,
#   'launched': 2014,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4ea133'),
#   'name': 'Your Way Game Board',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'goal': 250000.0,
#   'launched': 2014,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4ea144'),
#   'name': 'Endorsit: Reviewed by You... Endorsed by the Community',
#   'category': 'Web',
#   'main_category': 'Journalism',
#   'goal': 200000.0,
#   'launched': 2016,
#   'pledged': 137.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 137.0,
#   'usd_pledged_real': 137.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4ea2e3'),
#   'name': 'Bobby Rush: Live at the Great Wall of China',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 200000.0,
#   'launched': 2013,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4ea353'),
#   'name': 'A Gangster Movie called,  GET LOUIE',
#   'category': 'Action',
#   'main_category': 'Film & Video',
#   'goal': 2000000.0,
#   'launched': 2015,
#   'pledged': 20.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 20.0,
#   'usd_pledged_real': 20.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4ea510'),
#   'name': 'Stark Drive Electric Bike',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 250000.0,
#   'launched': 2016,
#   'pledged': 17854.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 2622.0,
#   'usd_pledged_real': 17854.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4ea52e'),
#   'name': 'Atheism is Winning! (Canceled)',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'goal': 500000.0,
#   'launched': 2014,
#   'pledged': 0.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4ea558'),
#   'name': 'Metroryde technology for riders and independent operators',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'goal': 200000.0,
#   'launched': 2016,
#   'pledged': 155.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 155.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4ea5a7'),
#   'name': 'GRANNY, The Movie (starring Jamie Kennedy) (Canceled)',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'goal': 500000.0,
#   'launched': 2013,
#   'pledged': 601.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 601.0,
#   'usd_pledged_real': 601.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4ea5b0'),
#   'name': 'Wining and Dining on the Yacht',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'goal': 250000.0,
#   'launched': 2015,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4ea5c0'),
#   'name': 'Saving Trayvon',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 200000.0,
#   'launched': 2012,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4ea63c'),
#   'name': 'Trendy - Style Simplified',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'goal': 200000.0,
#   'launched': 2016,
#   'pledged': 15.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 15.0,
#   'usd_pledged_real': 15.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4ea682'),
#   'name': 'The Citizen Body Camera with Tamper-proof Online Backup',
#   'category': 'Wearables',
#   'main_category': 'Technology',
#   'goal': 250000.0,
#   'launched': 2015,
#   'pledged': 167.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 167.0,
#   'usd_pledged_real': 167.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4ea6b5'),
#   'name': 'The Good Guys (Blood over Everything)',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 250000.0,
#   'launched': 2013,
#   'pledged': 202.06,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 202.06,
#   'usd_pledged_real': 202.06},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4ea6c3'),
#   'name': 'BAD PLANET',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 575000.0,
#   'launched': 2012,
#   'pledged': 45415.91,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 45415.91,
#   'usd_pledged_real': 45415.91},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4ea6d6'),
#   'name': 'Winthrop and Chester (Canceled)',
#   'category': 'Animation',
#   'main_category': 'Film & Video',
#   'goal': 200000.0,
#   'launched': 2013,
#   'pledged': 2930.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 2930.0,
#   'usd_pledged_real': 2930.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4ea713'),
#   'name': 'BodyCopter',
#   'category': 'Flight',
#   'main_category': 'Technology',
#   'goal': 2000000.0,
#   'launched': 2017,
#   'pledged': 240.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 240.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4ea717'),
#   'name': 'XCenter College Of Art, Music & Design',
#   'category': 'Civic Design',
#   'main_category': 'Design',
#   'goal': 10000000.0,
#   'launched': 2016,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4ea72c'),
#   'name': 'Rainbow Reef : a sit-com starring Ed Asner & Danilo DiJulio',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 400000.0,
#   'launched': 2014,
#   'pledged': 565.0,
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged': 565.0,
#   'usd_pledged_real': 565.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4ea72d'),
#   'name': 'Hotbox Hooka',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'goal': 450000.0,
#   'launched': 2015,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4ea736'),
#   'name': 'Save Black Earth Meats',
#   'category': 'Food',
#   'main_category': 'Food',
#   'goal': 225000.0,
#   'launched': 2014,
#   'pledged': 91116.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 91116.0,
#   'usd_pledged_real': 91116.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4ea788'),
#   'name': 'Spokios.tv',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'goal': 1500000.0,
#   'launched': 2015,
#   'pledged': 0.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fca2048f4c9c8ca3e4ea849'),
#   'name': 'Apparatus for harnessing solar energy Patent US 8,770,186 B2',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'goal': 20000000.0,
#   'launched': 2014,
#   'pledged': 4.0,
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged': 4.0,
#   'usd_pledged_real': 4.0},
#  ...]

# %% [markdown]
# ## Question 6

# %%
collection.create_index([("name",  "text")])
collection.index_information()
# Out:
# {'_id_': {'v': 2, 'key': [('_id', 1)]},
#  'name_text': {'v': 2,
#   'key': [('_fts', 'text'), ('_ftsx', 1)],
#   'weights': SON([('name', 1)]),
#   'default_language': 'english',
#   'language_override': 'language',
#   'textIndexVersion': 3}}

# %%
cur = collection.count_documents( { "$text": { "$search": "Sport" } } )
cur
# Out:
# 316
